# %% [markdown]
# ## Loading Elasticsearch
#
# In this section Elasticsearch is installed on the colab machine and initialised. The scripts to be able to run it on Colab were provided by GitHub user [korakot](https://gist.github.com/korakot/15fe4f18d0e0f53d7b834ef797880500).

# %%
# !wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-7.0.0-linux-x86_64.tar.gz -q # it's an older version of Elasticsearch, latest release being 7.13.4, couldn't make it run with that
# !tar -xzf elasticsearch-7.0.0-linux-x86_64.tar.gz
# !chown -R daemon:daemon elasticsearch-7.0.0
# !pip install elasticsearch -q
# Out:
#      |████████████████████████████████| 356 kB 7.6 MB/s

# %%
import os
from subprocess import Popen, PIPE, STDOUT

# %% [markdown]
# This cell runs Elasticsearch in the hosted runtime machine.

# %%
es_server = Popen(['elasticsearch-7.0.0/bin/elasticsearch'], 
                  stdout=PIPE, stderr=STDOUT,
                  preexec_fn=lambda: os.setuid(1)  # as daemon
                 )

# %% [markdown]
# The next command is using [cURL](https://curl.se/), which is used as a REST API to communicate with the Elasticsearch client. In this case it is adapting te request in query DSL (Elasticsearch's proprietary language). It's just checking if Elasticsearch is running locally (in the google machine in this case) by querying its default port (`localhost:9200`)

# %%
# !curl -X GET "localhost:9200/"
# Out:
# {
#   "name" : "d5c51a4a5492",
#   "cluster_name" : "elasticsearch",
#   "cluster_uuid" : "EFIdN210QWO4SY_U-OHaaQ",
#   "version" : {
#     "number" : "7.0.0",
#     "build_flavor" : "default",
#     "build_type" : "tar",
#     "build_hash" : "b7e28a7",
#     "build_date" : "2019-04-05T22:55:32.697037Z",
#     "build_snapshot" : false,
#     "lucene_version" : "8.0.0",
#     "minimum_wire_compatibility_version" : "6.7.0",
#     "minimum_index_compatibility_version" : "6.0.0-beta1"
#   },
#   "tagline" : "You Know, for Search"
# }

# %%
from elasticsearch import Elasticsearch

# %%
es = Elasticsearch()
es.ping() # another way to test whether ES is running, returns True if so
# Out:
# True

# %% [markdown]
# Elasticsearch should be running fine. Before creating an index, it is worth it to preprocess the data.
#
# ## Preprocessing

# %%
import pandas as pd
import numpy as np
import nltk
import re
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# Next cell loads the dataset. It is available on [Kaggle](https://www.kaggle.com/ashishgup/netflix-rotten-tomatoes-metacritic-imdb), it is currently being updated to the local runtime directly as using code to download it directly requires a personal Kaggle API  token.

# %%
films = pd.read_csv("netflix-rotten-tomatoes-metacritic-imdb.csv")
films.head()
# Out:
#                  Title  ... Trailer Site
# 0     Lets Fight Ghost  ...          NaN
# 1  HOW TO BUILD A GIRL  ...      YouTube
# 2           Centigrade  ...      YouTube
# 3                ANNE+  ...          NaN
# 4                Moxie  ...          NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# The next cell contains the preprocessing functions.

# %%
def query_processor(query):
    query = re.sub(r"(\w)([.,;:!?'\"”\)])", r"\1 \2", query)
    query = re.sub(r"([.,;:!?'\"“\(])(\w)", r"\1 \2", query)
    query = re.sub("'", "", query)
    query = re.sub(",", "", query)
    tokens = re.split(r"\s+",query)
    tokens = [t.lower() for t in tokens]
    # Stemming with the SnowballStemmer for more efficiency
    s_stemmer = SnowballStemmer("english")
    stemedList = []
    for word in tokens:
        stemedList.append(s_stemmer.stem(word))
    tokens = stemedList
    # Lemmatising the tokens
    wordnet_lemmatiser = WordNetLemmatizer()
    lemmaList = []
    for word in stemedList:
        lemmaList.append(wordnet_lemmatiser.lemmatize(word))
    tokens = lemmaList
    # Finally remove stopwords
    stops = set(stopwords.words("english"))
    tokens = [word for word in tokens if not word in stops]
    return tokens

def dataset_processor(dataset):
    dataset = pd.read_csv("netflix-rotten-tomatoes-metacritic-imdb.csv")
    dataset = dataset.drop(columns = ["Trailer Site", "TMDb Trailer", "Poster", "Image", "IMDb Votes", "Netflix Link", "Production House", "Netflix Release Date", "Boxoffice", "Awards Received", "Awards Nominated For", "IMDb Link", "Runtime", "Country Availability", "View Rating"])
    dataset["Average Score"] = dataset.apply(Average, axis = 1)
    dataset = dataset.drop(columns = ["Hidden Gem Score", "IMDb Score", "Rotten Tomatoes Score", "Metacritic Score"])
    dataset = dataset.astype({"Title":"str", "Genre":"str", "Tags":"str",
                     "Languages":"str", "Series or Movie":"category",
                     "Director":"str", "Writer":"str", "Actors":"str",
                     "Summary":"str", "Average Score":"float"})
    # So need to query processor the summary, genre list and tag list.
    for i in ["Summary", "Genre", "Tags"]:
      dataset[i] = dataset.loc[:, i].apply(query_processor)

    # Need to turn the director, writer, languages, and actors into a list.
    for i in ["Director", "Languages", "Writer", "Actors"]:
      dataset[i] = dataset.loc[:,i].apply(Split)

    # Change the release data to just the year
    dataset["Release Date"] = dataset["Release Date"].apply(Year)
    return dataset

def Split(row):
  tokens = re.split(",", row)
  return tokens

def Year(row):
  tokens = re.split(" ", str(row))
  if tokens[0] == "nan":
    return "NaN"
  else:
    return tokens[2]

def Average(row):
  scores = []
  scorers = ["Hidden Gem Score", "IMDb Score", "Rotten Tomatoes Score", "Metacritic Score"]
  potential = [10,10,100,100]
  for i in range(len(scorers)):
    if (np.isnan(row.loc[scorers[i]])) == False:
      scores.append(row.loc[scorers[i]]/potential[i])
  if len(scores) > 0:
    return sum(scores)/len(scores)
  else:
    return "NaN"

# %%
# preprocessing the dataset
films = dataset_processor(films)
films.head()
# Out:
#                  Title  ... Average Score
# 0     Lets Fight Ghost  ...         0.755
# 1  HOW TO BUILD A GIRL  ...         0.690
# 2           Centigrade  ...         0.510
# 3                ANNE+  ...         0.710
# 4                Moxie  ...         0.720
#
# [5 rows x 11 columns]

# %% [markdown]
# ## Indexing the documents

# %%
film_list = films.values.tolist()

# %%
film_list
# Out:
# [['Lets Fight Ghost',
#   ['crime', 'drama', 'fantasi', 'horror', 'romanc'],
#   ['comedi',
#    'programm',
#    'romant',
#    'tv',
#    'comedi',
#    'horror',
#    'programm',
#    'thai',
#    'tv',
#    'programm'],
#   ['Swedish', ' Spanish'],
#   'Series',
#   ['Tomas Alfredson'],
#   ['John Ajvide Lindqvist'],
#   ['Kåre Hedebrant', ' Per Ragnar', ' Lina Leandersson', ' Henrik Dahl'],
#   '2008',
#   ['med',
#    'student',
#    'supernatur',
#    'gift',
#    'tri',
#    'cash',
#    'abil',
#    'face',
#    'ghost',
#    'till',
#    'wander',
#    'spirit',
#    'bring',
#    'romanc',
#    'instead',
#    '.'],
#   0.755],
#  ['HOW TO BUILD A GIRL',
#   ['comedi'],
#   ['drama', 'comedi', 'film', 'base', 'book', 'british'],
#   ['English'],
#   'Movie',
#   ['Coky Giedroyc'],
#   ['Caitlin Moran'],
#   ['Paddy Considine', ' Cleo', ' Beanie Feldstein', ' Dónal Finn'],
#   '2020',
#   ['nerdi',
#    'johanna',
#    'move',
#    'london',
#    'thing',
#    'get',
#    'hand',
#    'reinvent',
#    'bad-mouth',
#    'music',
#    'critic',
#    'save',
#    'poverty-stricken',
#    'famili',
#    '.'],
#   0.69],
#  ['Centigrade',
#   ['drama', 'thriller'],
#   ['thriller'],
#   ['English'],
#   'Movie',
#   ['Brendan Walsh'],
#   ['Brendan Walsh', ' Daley Nixon'],
#   ['Genesis Rodriguez', ' Vincent Piazza'],
#   '2020',
#   ['trap',
#    'frozen',
#    'car',
#    'dure',
#    'blizzard',
#    'pregnant',
#    'woman',
#    'husband',
#    'fight',
#    'surviv',
#    'temperatur',
#    'plummet',
#    '.',
#    'inspir',
#    'true',
#    'stori',
#    '.'],
#   0.51],
#  ['ANNE+',
#   ['drama'],
#   ['tv', 'drama', 'romant', 'tv', 'drama', 'dutch', 'tv', 'show'],
#   ['Turkish'],
#   'Series',
#   ['nan'],
#   ['nan'],
#   ['Vahide Perçin', ' Gonca Vuslateri', ' Cansu Dere', ' Beren Gokyildiz'],
#   '2016',
#   ['upon',
#    'move',
#    'new',
#    'place',
#    '20-someth',
#    'run',
#    'former',
#    'flame',
#    'trigger',
#    'memori',
#    'past',
#    'relationship',
#    'sinc',
#    'split',
#    'four',
#    'year',
#    'ago',
#    '.'],
#   0.71],
#  ['Moxie',
#   ['anim', 'short', 'drama'],
#   ['social',
#    'issu',
#    'drama',
#    'teen',
#    'movi',
#    'drama',
#    'comedi',
#    'movi',
#    'base',
#    'book'],
#   ['English'],
#   'Movie',
#   ['Stephen Irwin'],
#   ['nan'],
#   ['Ragga Gudrun'],
#   '2011',
#   ['inspir',
#    'mom',
#    'rebelli',
#    'past',
#    'confid',
#    'new',
#    'friend',
#    'shi',
#    '16-year-old',
#    'publish',
#    'anonym',
#    'zine',
#    'call',
#    'sexism',
#    'school',
#    '.'],
#   0.72],
#  ['The Con-Heartist',
#   ['comedi', 'romanc'],
#   ['romant',
#    'comedi',
#    'comedi',
#    'romant',
#    'film',
#    'thai',
#    'comedi',
#    'thai',
#    'film'],
#   ['Thai'],
#   'Movie',
#   ['Mez Tharatorn'],
#   ['Pattaranad Bhiboonsawade', ' Thodsapon Thiptinnakorn', ' Mez Tharatorn'],
#   ['Thiti Mahayotaruk',
#    ' Nadech Kugimiya',
#    ' Kathaleeya McIntosh',
#    ' Pimchanok Leuwisetpaiboon'],
#   '2020',
#   ['ex-boyfriend',
#    'con',
#    'larg',
#    'sum',
#    'money',
#    'former',
#    'bank',
#    'employe',
#    'trick',
#    'scam',
#    'artist',
#    'help',
#    'swindl',
#    'retali',
#    '.'],
#   0.8],
#  ['Gleboka woda',
#   ['drama'],
#   ['tv', 'drama', 'polish', 'tv', 'show', 'social', 'issu', 'tv', 'drama'],
#   ['Polish'],
#   'Series',
#   ['nan'],
#   ['nan'],
#   ['Marcin Dorocinski',
#    ' Piotr Nowak',
#    ' Julia Kijowska',
#    ' Katarzyna Maciag'],
#   '2011',
#   ['group',
#    'social',
#    'welfar',
#    'worker',
#    'led',
#    'new',
#    'director',
#    'tri',
#    'provid',
#    'necessari',
#    'aid',
#    'peopl',
#    'struggl',
#    'various',
#    'problem',
#    '.'],
#   0.8099999999999999],
#  ['Instynkt',
#   ['crime'],
#   ['tv', 'drama', 'crime', 'tv', 'drama', 'polish', 'tv', 'show'],
#   ['Polish'],
#   'Series',
#   ['nan'],
#   ['nan'],
#   ['Pawel Królikowski',
#    ' Szymon Bobrowski',
#    ' Danuta Stenka',
#    ' Piotr Glowacki'],
#   '2011',
#   ['enigmat',
#    'commission',
#    'join',
#    'warsaw',
#    'polic',
#    'unconvent',
#    'investig',
#    'method',
#    'unsettl',
#    'offic',
#    'homicid',
#    'depart',
#    '.'],
#   0.54],
#  ['Only a Mother',
#   ['drama'],
#   ['social',
#    'issu',
#    'drama',
#    'drama',
#    'movi',
#    'base',
#    'book',
#    'period',
#    'piec',
#    'swedish',
#    'movi'],
#   ['Swedish'],
#   'Movie',
#   ['Alf Sjöberg'],
#   ['Ivar Lo-Johansson'],
#   ['Ulf Palme', ' Ragnar Falck', ' Hugo Björne', ' Eva Dahlbeck'],
#   '1949',
#   ['unhappili',
#    'marri',
#    'farm',
#    'worker',
#    'struggl',
#    'care',
#    'child',
#    'reflect',
#    'lost',
#    'youth',
#    'scandal',
#    'moment',
#    'cost',
#    'true',
#    'love',
#    '.'],
#   0.75],
#  ['Snowroller',
#   ['comedi'],
#   ['sport', 'movi', 'sport', 'comedi', 'comedi', 'swedish', 'movi'],
#   ['Swedish', ' English', ' German', ' Norwegian'],
#   'Movie',
#   ['Lasse Åberg'],
#   ['Lasse Åberg', ' Bo Jonsson'],
#   ['Jon Skolmen', ' Cecilia Walton', ' Lasse Åberg', ' Eva Millberg'],
#   '1985',
#   ['two',
#    'friend',
#    'take',
#    'ski',
#    'trip',
#    'alp',
#    'enjoy',
#    'outdoor',
#    'tri',
#    'charm',
#    'two',
#    'woman',
#    'also',
#    'vacat',
#    '.'],
#   0.595],
#  ['Sunes Summer',
#   ['comedi', 'famili', 'fantasi'],
#   ['child',
#    '&',
#    'famili',
#    'movi',
#    'comedi',
#    'movi',
#    'base',
#    'book',
#    'famili',
#    'featur',
#    'famili',
#    'comedi',
#    'swedish',
#    'movi'],
#   ['Swedish'],
#   'Movie',
#   ['Jon Holmberg'],
#   ['Jon Holmberg',
#    ' Daniella Mendel-Enk',
#    ' Sara Young',
#    ' Anders Jacobsson',
#    ' Sören Olsson'],
#   ['Elis Gerdt', ' Tea Stjärne', ' Fredrik Hallgren', ' Baxter Renman'],
#   '2018',
#   ['famili',
#    'camp',
#    'trip',
#    'goe',
#    'awri',
#    'boy',
#    'accident-pron',
#    'relat',
#    'comedi',
#    'base',
#    'book',
#    'seri',
#    'ander',
#    'jacobsson',
#    'sören',
#    'olsson',
#    '.'],
#   0.65],
#  ['The Invisible',
#   ['crime', 'drama', 'fantasi', 'mysteri', 'thriller'],
#   ['thriller',
#    'movi',
#    'movi',
#    'base',
#    'book',
#    'supernatur',
#    'thriller',
#    'swedish',
#    'movi'],
#   ['English'],
#   'Movie',
#   ['David S. Goyer'],
#   ['Christine Roum', ' Mats Wahl', ' Mick Davis'],
#   ['Marcia Gay Harden',
#    ' Chris Marquette',
#    ' Margarita Levieva',
#    ' Justin Chatwin'],
#   '2007',
#   ['critic',
#    'injur',
#    'brutal',
#    'beat',
#    'teenag',
#    'aspir',
#    'poet',
#    'find',
#    'suspend',
#    'life',
#    'death',
#    'invis',
#    '.'],
#   0.345],
#  ['The Simple Minded Murderer',
#   ['drama'],
#   ['social',
#    'issu',
#    'drama',
#    'drama',
#    'movi',
#    'base',
#    'book',
#    'period',
#    'piec',
#    'classic',
#    'movi',
#    'swedish',
#    'movi'],
#   ['Scanian', ' Swedish'],
#   'Movie',
#   ['Hans Alfredson'],
#   ['Hans Alfredson'],
#   ['Stellan Skarsgård', ' Hans Alfredson', ' Per Myrberg', ' Maria Johansson'],
#   '1985',
#   ['good-natur',
#    'farmhand',
#    'perpetu',
#    'terror',
#    'cruel',
#    'bos',
#    'disabl',
#    'find',
#    'love',
#    'accept',
#    'poor',
#    'famili',
#    'take',
#    '.'],
#   0.82],
#  ['The Stig-Helmer Story',
#   ['comedi', 'drama'],
#   ['romant',
#    'drama',
#    'romant',
#    'comedi',
#    'drama',
#    'comedi',
#    'romant',
#    'movi',
#    'swedish',
#    'movi'],
#   ['Swedish', ' English'],
#   'Movie',
#   ['Lasse Åberg'],
#   ['Lasse Åberg'],
#   ['Jon Skolmen', ' Ida Högberg', ' Lasse Åberg', ' Tobias Jacobsson'],
#   '2011',
#   ['popular',
#    'charact',
#    'stig-helm',
#    'olsson',
#    'recount',
#    'life',
#    'reminisc',
#    'youth',
#    'tri',
#    'track',
#    'first',
#    'love',
#    '.'],
#   0.545],
#  ['To Kill a Child',
#   ['short', 'drama'],
#   ['drama', 'swedish', 'movi'],
#   ['Spanish'],
#   'Movie',
#   ['José Esteban Alenda', ' César Esteban Alenda'],
#   ['José Esteban Alenda', ' Victoria Ruiz', ' César Esteban Alenda'],
#   ['Manolo Solo', ' Roger Príncep', ' Cristina Marcos', ' Roger Álvarez'],
#   '2011',
#   ['car',
#    'accid',
#    'involv',
#    'young',
#    'child',
#    'take',
#    'devast',
#    'toll',
#    '9-minut',
#    'film',
#    'base',
#    '1948',
#    'short',
#    'stori',
#    'writer',
#    'stig',
#    'dagerman',
#    '.'],
#   0.8250000000000001],
#  ['Joker',
#   ['crime', 'drama', 'thriller'],
#   ['dark',
#    'comedi',
#    'crime',
#    'comedi',
#    'drama',
#    'comedi',
#    'crime',
#    'drama',
#    'swedish',
#    'movi'],
#   ['English'],
#   'Movie',
#   ['Todd Phillips'],
#   ['Scott Silver',
#    ' Jerry Robinson',
#    ' Todd Phillips',
#    ' Bob Kane',
#    ' Bill Finger'],
#   ['Joaquin Phoenix', ' Zazie Beetz', ' Robert De Niro', ' Frances Conroy'],
#   '2019',
#   ['practic',
#    'joker',
#    'fake',
#    'kidnap',
#    'bachelor',
#    'parti',
#    'turn',
#    'real',
#    'abduct',
#    'forc',
#    'infiltr',
#    'terrorist',
#    'group',
#    'rescu',
#    'groom',
#    '.'],
#   0.615],
#  ['I',
#   ['action', 'adventur', 'fantasi', 'sci-fi'],
#   ['drama', 'swedish', 'movi'],
#   ['English', ' Sanskrit'],
#   'Movie',
#   ['George Lucas'],
#   ['George Lucas'],
#   ['Liam Neeson', ' Ewan McGregor', ' Natalie Portman', ' Jake Lloyd'],
#   '1999',
#   ['young',
#    'man',
#    'seek',
#    'ident',
#    'begin',
#    'romanc',
#    'becom',
#    'complic',
#    'marriag',
#    'avant-gard',
#    'drama',
#    'filmmak',
#    'peter',
#    'kylberg',
#    '.'],
#   0.49],
#  ['Harrys Daughters',
#   ['adventur', 'drama', 'fantasi', 'mysteri'],
#   ['drama', 'swedish', 'movi'],
#   ['English'],
#   'Movie',
#   ['David Yates'],
#   ['Steve Kloves', ' J.K. Rowling'],
#   ['Ralph Fiennes', ' Alan Rickman', ' Michael Gambon', ' Daniel Radcliffe'],
#   '2011',
#   ['two',
#    'sister',
#    'experi',
#    'pregnanc',
#    'tragedi',
#    'rattl',
#    'bond',
#    'bring',
#    'secret',
#    'jealousi',
#    'sorrow',
#    'forefront',
#    'relationship',
#    '.'],
#   0.765],
#  ['Gyllene Tider',
#   ['music'],
#   ['music',
#    '&',
#    'music',
#    'swedish',
#    'movi',
#    'music',
#    '&',
#    'concert',
#    'documentari',
#    'documentari',
#    'film',
#    'concert'],
#   ['Swedish'],
#   'Movie',
#   ['Lasse Hallström'],
#   ['nan'],
#   ['Micke Andersson', ' Anders Herrlin', ' Göran Fritzson', ' Per Gessle'],
#   'NaN',
#   ['music',
#    'documentari',
#    'offer',
#    'backstag',
#    'interview',
#    'concert',
#    'footag',
#    'swedish',
#    'pop',
#    'group',
#    'peak',
#    'popular',
#    'earli',
#    '80',
#    '.'],
#   0.8250000000000001],
#  ['False As Water',
#   ['drama', 'thriller'],
#   ['psycholog', 'thriller', 'drama', 'thriller', 'movi', 'swedish', 'movi'],
#   ['Swedish'],
#   'Movie',
#   ['Hans Alfredson'],
#   ['Hans Alfredson'],
#   ['Marie Göranzon',
#    ' Stellan Skarsgård',
#    ' Sverre Anker Ousdal',
#    ' Malin Ek'],
#   '1985',
#   ['illicit',
#    'romanc',
#    'marri',
#    'publish',
#    'poet',
#    'turn',
#    'fraught',
#    'strang',
#    'happen',
#    'apart',
#    'push',
#    'mental',
#    'health',
#    'brink',
#    '.'],
#   0.71],
#  ['Bang!',
#   ['short'],
#   ['drama', 'movi', 'base', 'book', 'swedish', 'movi'],
#   ['nan'],
#   'Movie',
#   ['Robert Breer'],
#   ['nan'],
#   ['nan'],
#   'NaN',
#   ['lone',
#    'teacher',
#    'muddl',
#    'midlif',
#    'crisi',
#    'navig',
#    'romant',
#    'relationship',
#    'tri',
#    'hand',
#    'compos',
#    'experiment',
#    'music',
#    '.'],
#   0.665],
#  ['A Guest Is Coming',
#   ['thriller'],
#   ['crime',
#    'movi',
#    'thriller',
#    'movi',
#    'mysteri',
#    'crime',
#    'thriller',
#    'classic',
#    'movi',
#    'swedish',
#    'movi'],
#   ['Swedish'],
#   'Movie',
#   ['Arne Mattsson'],
#   ['Stieg Trenter'],
#   ['Karl-Arne Holmsten',
#    ' Sture Lagerwall',
#    ' Naima Wifstrand',
#    " Erik 'Bullen' Berglund"],
#   '1947',
#   ['sleuth',
#    'writer',
#    'investig',
#    'strang',
#    'murder',
#    'old',
#    'man',
#    'decid',
#    'sell',
#    'manor',
#    'famili',
#    'wish',
#    '.'],
#   0.655],
#  ['1939',
#   ['drama'],
#   ['swedish', 'movi', 'drama'],
#   ['Swedish'],
#   'Movie',
#   ['Göran Carmback'],
#   ['Catti Edfeldt', ' Kjell Sundstedt', ' Brasse Brännström'],
#   ['Helene Egelund', ' Ingvar Hirdwall', ' Per Morberg', ' Helena Bergström'],
#   '1989',
#   ['young',
#    'woman',
#    'neutral',
#    'sweden',
#    'dure',
#    'world',
#    'war',
#    'ii',
#    'move',
#    'stockholm',
#    'marri',
#    'man',
#    'turn',
#    'differ',
#    'imagin',
#    '.'],
#   0.655],
#  ['Girls und Panzer das Finale',
#   ['anim', 'action', 'comedi'],
#   ['drama',
#    'anim',
#    'action',
#    '&',
#    'adventur',
#    'action',
#    'anim',
#    'anim',
#    'movi',
#    'japanes',
#    'movi',
#    'school',
#    'anim',
#    'militari',
#    '&',
#    'war',
#    'anim'],
#   ['Japanese'],
#   'Series',
#   ['Tsutomu Mizushima'],
#   ['Reiko Yoshida'],
#   ['Mami Ozaki', ' Ikumi Nakagami', ' Mai Fuchigami', ' Ai Kayano'],
#   '2017',
#   ['girl',
#    'oarai',
#    'tankeri',
#    'team',
#    'look',
#    'forward',
#    'finish',
#    'school',
#    'year',
#    'peac',
#    'befor',
#    'know',
#    'theyr',
#    'back',
#    'battlefield',
#    '.'],
#   0.79],
#  ['Indoo Ki Jawani',
#   ['comedi', 'drama'],
#   ['action',
#    '&',
#    'adventur',
#    'bollywood',
#    'film',
#    'comedi',
#    'adventur',
#    'romant',
#    'film',
#    'indian',
#    'film',
#    'hindi-languag',
#    'film'],
#   ['Hindi'],
#   'Movie',
#   ['Abir Sengupta'],
#   ['Abir Sengupta'],
#   ['Rakesh Bedi', ' Aditya Seal', ' Kiara Advani', ' Iqbal Khan'],
#   '2020',
#   ['spirit',
#    'naiv',
#    'young',
#    'woman',
#    'seek',
#    'one-night',
#    'stand',
#    'discov',
#    'date',
#    'real',
#    'ident',
#    'thing',
#    'quick',
#    'go',
#    'casual',
#    'complic',
#    '.'],
#   0.265],
#  ['The Coroner',
#   ['crime', 'drama'],
#   ['mysteri',
#    'programm',
#    'drama',
#    'programm',
#    'crime',
#    'tv',
#    'drama',
#    'canadian',
#    'tv',
#    'programm',
#    'tv',
#    'programm',
#    'base',
#    'book'],
#   ['English'],
#   'Series',
#   ['nan'],
#   ['Sally Abbott'],
#   ['Beatie Edney', ' Claire Goose', ' Oliver Gomm', ' Matt Bardock'],
#   '2015',
#   ['month',
#    'person',
#    'tragedi',
#    'doctor',
#    'take',
#    'job',
#    'coron',
#    'investig',
#    'seri',
#    'suspici',
#    'death',
#    'toronto',
#    '.'],
#   0.74],
#  ['Brave New World',
#   ['drama', 'sci-fi'],
#   ['tv',
#    'drama',
#    'u',
#    'tv',
#    'show',
#    'tv',
#    'show',
#    'base',
#    'book',
#    'sci-fi',
#    'tv'],
#   ['English'],
#   'Series',
#   ['nan'],
#   ['David Wiener', ' Brian Taylor', ' Grant Morrison'],
#   ['Nina Sosanya',
#    ' Harry Lloyd',
#    ' Jessica Brown Findlay',
#    ' Alden Ehrenreich'],
#   '2020',
#   ['rebelli',
#    'stranger',
#    'arriv',
#    'anoth',
#    'land',
#    'resid',
#    'new',
#    'london',
#    'begin',
#    'question',
#    'rule',
#    'seem',
#    'utopian',
#    'societi',
#    '.'],
#   0.5449999999999999],
#  ['Comrades: Almost a Love Story',
#   ['drama', 'romanc'],
#   ['romant',
#    'drama',
#    'chine',
#    'movi',
#    'drama',
#    'romant',
#    'movi',
#    'hong',
#    'kong',
#    'movi',
#    'romant',
#    'favorit'],
#   ['Cantonese', ' Mandarin', ' English'],
#   'Movie',
#   ['Peter Ho-Sun Chan'],
#   ['Ivy Ho'],
#   ['Maggie Cheung', ' Leon Lai', ' Eric Tsang', ' Kristy Yeung'],
#   '1996',
#   ['two',
#    'young',
#    'chine',
#    'mainland',
#    'transplant',
#    'hong',
#    'kong',
#    '--',
#    'naiv',
#    'xiao-jun',
#    'li',
#    'street-smart',
#    'qiao',
#    'li',
#    '--',
#    'becom',
#    'fast',
#    'friend',
#    'tri',
#    'fall',
#    'love',
#    'despit',
#    'deepen',
#    'feel',
#    '.'],
#   0.79],
#  ['The Closet',
#   ['comedi'],
#   ['korean', 'movi', 'horror', 'movi', 'mysteri'],
#   ['French'],
#   'Movie',
#   ['Francis Veber'],
#   ['Francis Veber'],
#   ['Gérard Depardieu',
#    ' Michèle Laroque',
#    ' Daniel Auteuil',
#    ' Thierry Lhermitte'],
#   '2001',
#   ['recent',
#    'widow',
#    'move',
#    'new',
#    'hous',
#    'take',
#    'chill',
#    'turn',
#    'daughter',
#    'vanish',
#    '—',
#    'onli',
#    'mysteri',
#    'exorcist',
#    'seem',
#    'answer',
#    '.'],
#   0.6625000000000001],
#  ['The Mysterians',
#   ['action', 'famili', 'sci-fi', 'thriller'],
#   ['sci-fi',
#    '&',
#    'fantasi',
#    'alien',
#    'sci-fi',
#    'japanes',
#    'movi',
#    'classic',
#    'movi'],
#   ['Japanese', ' English'],
#   'Movie',
#   ['Ishirô Honda'],
#   ['Shigeru Kayama', ' Jôjirô Okami', ' Takeshi Kimura'],
#   ['Yumi Shirakawa', ' Akihiko Hirata', ' Kenji Sahara', ' Momoko Kôchi'],
#   '1959',
#   ['mankind',
#    'face',
#    'imposs',
#    'choic',
#    'alien',
#    'race',
#    'request',
#    'use',
#    'small',
#    'plot',
#    'land',
#    'permiss',
#    'procreat',
#    'earth',
#    'woman',
#    '.'],
#   0.6133333333333334],
#  ['No Longer Human',
#   ['biographi', 'drama', 'thriller'],
#   ['romant', 'drama', 'drama', 'romant', 'movi', 'japanes', 'movi'],
#   ['Japanese'],
#   'Movie',
#   ['Mika Ninagawa'],
#   ['Kaeko Hayafune'],
#   ['Tatsuya Fujiwara', ' Kengo Kôra', ' Yûdai Chiba', ' Rie Miyazawa'],
#   '2019',
#   ['writer',
#    'osamu',
#    'dazai',
#    'vacil',
#    'life',
#    'death',
#    'three',
#    'separ',
#    'woman',
#    'wallow',
#    'moral',
#    'filth',
#    'reckless',
#    'pursuit',
#    'artist',
#    'inspir',
#    '.'],
#   0.685],
#  ['Repast',
#   ['drama'],
#   ['drama', 'movi', 'base', 'book', 'japanes', 'movi', 'classic', 'movi'],
#   ['Japanese'],
#   'Movie',
#   ['Mikio Naruse'],
#   ['Sumie Tanaka', ' Yasunari Kawabata', ' Fumiko Hayashi', ' Toshirô Ide'],
#   ['Yukiko Shimazaki', ' Setsuko Hara', ' Ken Uehara', ' Yôko Sugi'],
#   '1951',
#   ['woman',
#    'struggl',
#    'keep',
#    'spirit',
#    'aliv',
#    'drudgeri',
#    'marri',
#    'exist',
#    'move',
#    'tokyo',
#    'osaka',
#    'husband',
#    '.'],
#   0.8266666666666667],
#  ['Sway',
#   ['crime', 'drama'],
#   ['courtroom', 'drama', 'drama', 'mysteri', 'japanes', 'movi'],
#   ['Japanese'],
#   'Movie',
#   ['Miwa Nishikawa'],
#   ['Miwa Nishikawa'],
#   ['Masatô Ibu', ' Hirofumi Arai', ' Joe Odagiri', ' Teruyuki Kagawa'],
#   '2006',
#   ['tokyo',
#    'photograph',
#    'return',
#    'home',
#    'mother',
#    'memori',
#    'servic',
#    'old',
#    'grudg',
#    'ignit',
#    'tragedi',
#    '.',
#    'brother',
#    'arrest',
#    'blame',
#    '?'],
#   0.8099999999999999],
#  ['When a Woman Ascends the Stairs',
#   ['drama'],
#   ['social', 'issu', 'drama', 'drama', 'japanes', 'movi', 'classic', 'movi'],
#   ['Japanese'],
#   'Movie',
#   ['Mikio Naruse'],
#   ['Ryûzô Kikushima'],
#   ['Hideko Takamine', ' Tatsuya Nakadai', ' Masayuki Mori', ' Reiko Dan'],
#   '1963',
#   ['face',
#    'option',
#    'widow',
#    'bar',
#    'hostess',
#    'entertain',
#    'businessmen',
#    'cutthroat',
#    'ginza',
#    'district',
#    'tri',
#    'desper',
#    'better',
#    'circumst',
#    '.'],
#   0.8566666666666666],
#  ['Yearning',
#   ['drama'],
#   ['romant',
#    'drama',
#    'drama',
#    'romant',
#    'movi',
#    'japanes',
#    'movi',
#    'classic',
#    'movi'],
#   ['Japanese'],
#   'Movie',
#   ['Mikio Naruse'],
#   ['Zenzô Matsuyama', ' Mikio Naruse'],
#   ['Hideko Takamine', ' Yumi Shirakawa', ' Mitsuko Kusabue', ' Yûzô Kayama'],
#   '1964',
#   ['widow',
#    'torment',
#    'mean-spirit',
#    'scheme',
#    'late',
#    'husband',
#    'famili',
#    'rakish',
#    'young',
#    'brother-in-law',
#    'sudden',
#    'declar',
#    'love',
#    '.'],
#   0.8466666666666667],
#  ['Gorath',
#   ['action', 'famili', 'sci-fi', 'thriller'],
#   ['sci-fi', '&', 'fantasi', 'japanes', 'movi'],
#   ['Japanese', ' English'],
#   'Movie',
#   ['Ishirô Honda'],
#   ['John Meredyth Lucas', ' Jôjirô Okami', ' Takeshi Kimura'],
#   ['Yumi Shirakawa', ' Kumi Mizuno', ' Akira Kubo', ' Ryô Ikebe'],
#   '1964',
#   ['gravit',
#    'den',
#    'runaway',
#    'star',
#    'collis',
#    'cours',
#    'earth',
#    'scientist',
#    'devi',
#    'dare',
#    'plan',
#    'shift',
#    'planet',
#    'harm',
#    'way',
#    '.'],
#   0.5433333333333333],
#  ['Ginza Cosmetics',
#   ['drama'],
#   ['drama', 'movi', 'base', 'book', 'japanes', 'movi', 'classic', 'movi'],
#   ['Japanese', ' English'],
#   'Movie',
#   ['Mikio Naruse'],
#   ['Matsuo Kishi', ' Tomoichirô Inoue'],
#   ['Yûji Hori', ' Kyôko Kagawa', ' Ranko Hanai', ' Kinuyo Tanaka'],
#   '1951',
#   ['bar',
#    'hostess',
#    'ginza',
#    'struggl',
#    'make',
#    'end',
#    'meet',
#    'parent',
#    'son',
#    'grappl',
#    'loyalti',
#    'friend',
#    'custom',
#    'expect',
#    '.'],
#   0.6366666666666666],
#  ['Floating Clouds',
#   ['drama', 'romanc'],
#   ['romant',
#    'drama',
#    'social',
#    'issu',
#    'drama',
#    'drama',
#    'romant',
#    'movi',
#    'movi',
#    'base',
#    'book',
#    'japanes',
#    'movi',
#    'classic',
#    'movi'],
#   ['Japanese'],
#   'Movie',
#   ['Mikio Naruse'],
#   ['Yôko Mizuki', ' Fumiko Hayashi'],
#   ['Hideko Takamine', ' Isao Yamagata', ' Mariko Okada', ' Masayuki Mori'],
#   '1980',
#   ['return',
#    'japan',
#    'war',
#    'woman',
#    'rekindl',
#    'affair',
#    'man',
#    'met',
#    'french',
#    'indochina',
#    'remain',
#    'unmoor',
#    'postwar',
#    'societi',
#    '.'],
#   0.7933333333333333],
#  ['Cheer Boys!!',
#   ['anim', 'drama', 'sport'],
#   ['teen',
#    'movi',
#    'drama',
#    'sport',
#    'drama',
#    'movi',
#    'base',
#    'book',
#    'japanes',
#    'movi',
#    'youth',
#    'movi',
#    'japanes',
#    'youth',
#    'drama'],
#   ['Japanese'],
#   'Movie',
#   ['nan'],
#   ['nan'],
#   ['Jarrod Greene', ' Cris George', ' Dallas Reid', ' Justin Pate'],
#   '2016',
#   ['injuri',
#    'end',
#    'judo',
#    'career',
#    'colleg',
#    'student',
#    'best',
#    'friend',
#    'start',
#    'men',
#    'cheer',
#    'team',
#    'assembl',
#    'squad',
#    'misfit',
#    'aim',
#    'top',
#    '.'],
#   0.73],
#  ['365 Nights',
#   ['nan'],
#   ['romant',
#    'drama',
#    'drama',
#    'romant',
#    'movi',
#    'movi',
#    'base',
#    'book',
#    'japanes',
#    'movi',
#    'classic',
#    'movi'],
#   ['Japanese'],
#   'Movie',
#   ['Kon Ichikawa'],
#   ['Kennosuke Tateoka', ' Masajiro Tojima'],
#   ['Hideko Takamine', ' Chizuko Nogami', ' Yûji Hori', ' Ken Uehara'],
#   'NaN',
#   ['kuroku',
#    'flee',
#    'osaka',
#    '—',
#    'near',
#    'bankrupt',
#    'father',
#    'pressur',
#    'marri',
#    'daughter',
#    'wealthi',
#    'man',
#    '—',
#    'fall',
#    'young',
#    'woman',
#    'tokyo',
#    '.'],
#   0.66],
#  ['Restart After Come Back Home',
#   ['drama', 'romanc'],
#   ['romant',
#    'drama',
#    'drama',
#    'lgbtq',
#    'movi',
#    'romant',
#    'movi',
#    'japanes',
#    'movi'],
#   ['Japanese'],
#   'Movie',
#   ['Ryûta Inoue'],
#   ['Kumiko Satô'],
#   ['Masahiro Kômoto', ' Yukijirô Hotaru', ' Eri Murakawa', ' Yûki Furukawa'],
#   '2020',
#   ['mitsuomi',
#    'move',
#    'back',
#    'home',
#    'ten',
#    'exhaust',
#    'year',
#    'citi',
#    'grow',
#    'affect',
#    'guy',
#    'neighborhood',
#    'help',
#    'heal',
#    'weari',
#    'soul',
#    '.'],
#   0.79],
#  ['Trial by Fire',
#   ['biographi', 'drama'],
#   ['film', 'base', 'real', 'life', 'social', 'issu', 'drama', 'drama'],
#   ['English'],
#   'Movie',
#   ['Edward Zwick'],
#   ['Geoffrey Fletcher', ' David Grann'],
#   ['Laura Dern', " Jack O'Connell", ' Emily Meade', ' Chris Coy'],
#   '2019',
#   ['woman',
#    'develop',
#    'close',
#    'relationship',
#    'death',
#    'row',
#    'inmat',
#    'set',
#    'prove',
#    'man',
#    'wa',
#    'wrong',
#    'convict',
#    'kill',
#    'child',
#    'fire',
#    '.'],
#   0.6074999999999999],
#  ['5 Minute',
#   ['comedi'],
#   ['social', 'issu', 'drama', 'drama', 'lgbtq', 'movi', 'independ', 'movi'],
#   ['English'],
#   'Movie',
#   ['nan'],
#   ['nan'],
#   ['Jeff Lewis'],
#   '2010',
#   ['violent',
#    'homophob',
#    'attack',
#    'break',
#    'dure',
#    'film',
#    'screen',
#    'bold',
#    'journalist',
#    'pursu',
#    'justic',
#    'lgbtq',
#    'communiti',
#    '.',
#    'base',
#    'true',
#    'event',
#    '.'],
#   0.895],
#  ['Dilili in Paris',
#   ['anim', 'adventur', 'famili', 'mysteri'],
#   ['child', '&', 'famili', 'movi', 'famili', 'adventur', 'anim', 'movi'],
#   ['French'],
#   'Movie',
#   ['Michel Ocelot'],
#   ['Michel Ocelot'],
#   ['Prunelle Charles-Ambron',
#    ' Bruno Paviot',
#    ' Natalie Dessay',
#    ' Enzo Ratsito'],
#   '2019',
#   ['stow',
#    'away',
#    'ship',
#    'new',
#    'caledonia',
#    'dilili',
#    'set',
#    'solv',
#    'mysteri',
#    'behind',
#    'kidnap',
#    'young',
#    'girl',
#    'pari',
#    '.'],
#   0.6],
#  ['All of Us',
#   ['comedi'],
#   ['belgian', 'movi', 'drama', 'documentari', 'film'],
#   ['English'],
#   'Movie',
#   ['nan'],
#   ['Jada Pinkett Smith', ' Will Smith', ' Betsy Borns'],
#   ['Duane Martin', ' Khamani Griffin', ' LisaRaye McCoy', ' Tony Rock'],
#   '2003',
#   ['self-help',
#    'group',
#    'led',
#    'untri',
#    'therapist',
#    'four',
#    'peopl',
#    'termin',
#    'ill',
#    'face',
#    'uncomfort',
#    'truth',
#    'tri',
#    'live',
#    'moment',
#    '.'],
#   0.66],
#  ['Years and Years',
#   ['drama', 'sci-fi'],
#   ['tv', 'drama', 'polit', 'tv', 'show', 'british'],
#   ['English'],
#   'Series',
#   ['nan'],
#   ['Russell T. Davies'],
#   ['Anne Reid', " T'Nia Miller", ' Rory Kinnear', ' Ruth Madeley'],
#   '2019',
#   ['fate',
#    'night',
#    '2019',
#    'futur',
#    'britain',
#    'live',
#    'ordinari',
#    'famili',
#    'chang',
#    'dramat',
#    'cours',
#    'next',
#    '15',
#    'year',
#    '.'],
#   0.625],
#  ['The New Pope',
#   ['drama'],
#   ['tv', 'drama', 'italian', 'tv', 'show'],
#   ['English', ' Italian'],
#   'Series',
#   ['nan'],
#   ['Paolo Sorrentino'],
#   ['Jude Law', ' Cécile de France', ' Silvio Orlando', ' John Malkovich'],
#   '2020',
#   ['young',
#    'pope',
#    'commiss',
#    'new',
#    'leader',
#    'step',
#    '.',
#    'lie',
#    'hidden',
#    'agenda',
#    'start',
#    'vatican',
#    'problem',
#    '.'],
#   0.615],
#  ['Life and Nothing But',
#   ['drama', 'war'],
#   ['drama', 'period', 'piec', 'award-win', 'drama', 'french'],
#   ['French'],
#   'Movie',
#   ['Bertrand Tavernier'],
#   ['Jean Cosmos', ' Bertrand Tavernier'],
#   ['Maurice Barrier', ' Philippe Noiret', ' Sabine Azéma', ' Pascale Vignal'],
#   '1989',
#   ['maj',
#    '.',
#    'dellaplan',
#    'militari',
#    'man',
#    'world',
#    'war',
#    'take',
#    'unenvi',
#    'emot',
#    'pain',
#    'task',
#    'sift',
#    'bodi',
#    'men',
#    'kill',
#    'verdun',
#    'countrysid',
#    'help',
#    'relat',
#    'identifi',
#    '.'],
#   0.8066666666666666],
#  ['Let Joy Reign Supreme',
#   ['drama', 'histori', 'war'],
#   ['drama', 'period', 'piec', 'french'],
#   ['French', ' Breton'],
#   'Movie',
#   ['Bertrand Tavernier'],
#   ['Jean Aurenche', ' Bertrand Tavernier'],
#   ['Philippe Noiret',
#    ' Christine Pascal',
#    ' Jean-Pierre Marielle',
#    ' Jean Rochefort'],
#   '1975',
#   ['eye',
#    'ambiti',
#    'priest',
#    'libertin',
#    'philipp',
#    'ii',
#    'revel',
#    'scandal',
#    'rule',
#    '18th-centuri',
#    'franc',
#    'satir',
#    'drama',
#    '.'],
#   0.77],
#  ['Coup de Torchon',
#   ['comedi', 'crime', 'drama'],
#   ['drama', 'comedi', 'movi', 'base', 'book', 'french'],
#   ['French', ' English'],
#   'Movie',
#   ['Bertrand Tavernier'],
#   ['Jean Aurenche', ' Jim Thompson', ' Bertrand Tavernier'],
#   ['Jean-Pierre Marielle',
#    ' Philippe Noiret',
#    ' Isabelle Huppert',
#    ' Stéphane Audran'],
#   '1981',
#   ['1930s',
#    'coloni',
#    'seneg',
#    'polic',
#    'offic',
#    'decid',
#    'seek',
#    'vengeanc',
#    'enemi',
#    'adapt',
#    'jim',
#    'thompson',
#    'pulp',
#    'novel',
#    '"',
#    'pop',
#    '.',
#    '1280',
#    '."'],
#   0.7400000000000001],
#  ['Valley of the Gods',
#   ['adventur', 'drama', 'sci-fi', 'thriller'],
#   ['drama', 'polish', 'movi', 'polish', 'drama'],
#   ['English'],
#   'Movie',
#   ['Lech Majewski'],
#   ['Lech Majewski'],
#   ['Josh Hartnett', ' Bérénice Marlohe', ' Keir Dullea', ' John Malkovich'],
#   '2020',
#   ['struggl',
#    'writer',
#    'embark',
#    'pen',
#    'biographi',
#    'industri',
#    'magnat',
#    'ha',
#    'design',
#    'land',
#    'sacr',
#    'navajo',
#    'communiti',
#    '.'],
#   0.575],
#  ['Framing John DeLorean',
#   ['documentari', 'biographi', 'drama'],
#   ['biograph', 'documentari', 'drama', 'documentari', 'film'],
#   ['English'],
#   'Movie',
#   ['Don Argott', ' Sheena M. Joyce'],
#   ['Alexandra Orton', ' Dan Greeney'],
#   ['Morena Baccarin', ' Alec Baldwin', ' Dean Winters', ' Josh Charles'],
#   '2019',
#   ['rise',
#    'auto',
#    'industri',
#    'fall',
#    'grace',
#    'follow',
#    'john',
#    'delorean',
#    'incred',
#    'legaci',
#    'power',
#    'polit',
#    'fast',
#    'car',
#    'illicit',
#    'drug',
#    '.'],
#   0.755],
#  ['Critters Attack!',
#   ['comedi', 'horror', 'sci-fi'],
#   ['dark',
#    'comedi',
#    'sci-fi',
#    '&',
#    'fantasi',
#    'comedi',
#    'creatur',
#    'featur',
#    'horror',
#    'movi',
#    'horror',
#    'comedi'],
#   ['English'],
#   'Movie',
#   ['Bobby Miller'],
#   ['Scott Lobdell'],
#   ['Tashiana Washington', ' Jaeden Noel', ' Jack Fulton', ' Ava Preston'],
#   '2020',
#   ['babysitt',
#    'bore',
#    'charg',
#    'take',
#    'hike',
#    '—',
#    'straight',
#    'clutch',
#    'voraci',
#    'alien',
#    '.',
#    'luckili',
#    'mysteri',
#    'woman',
#    'histori',
#    'isnt',
#    'far',
#    'behind',
#    '.'],
#   0.47],
#  ['The Bold Type',
#   ['drama'],
#   ['tv', 'comedi', 'tv', 'drama', 'u', 'tv', 'show'],
#   ['English'],
#   'Series',
#   ['nan'],
#   ['Sarah Watson'],
#   ['Meghann Fahy', ' Melora Hardin', ' Katie Stevens', ' Aisha Dee'],
#   '2017',
#   ['woman',
#    'magazin',
#    'new',
#    'york',
#    'three',
#    'millenni',
#    'juggl',
#    'career',
#    'romanc',
#    'friendship',
#    'big-citi',
#    'life',
#    'find',
#    'voic',
#    '.'],
#   0.605],
#  ['Alice',
#   ['comedi', 'romanc'],
#   ['tv',
#    'mysteri',
#    'tv',
#    'drama',
#    'korean',
#    'tv',
#    'show',
#    'tv',
#    'thriller',
#    'futurist',
#    'sci-fi',
#    'sci-fi',
#    'tv'],
#   ['English', ' Cantonese'],
#   'Series',
#   ['Woody Allen'],
#   ['Woody Allen'],
#   ['June Squibb', ' Mia Farrow', ' William Hurt', ' Joe Mantegna'],
#   '1991',
#   ['investig',
#    'string',
#    'murder',
#    'detect',
#    'stun',
#    'encount',
#    'time',
#    'travel',
#    '—',
#    'especi',
#    'professor',
#    'dead',
#    'ringer',
#    'mother',
#    '.'],
#   0.6074999999999999],
#  ['Lobster Cop',
#   ['comedi', 'crime'],
#   ['dark',
#    'comedi',
#    'action',
#    '&',
#    'adventur',
#    'chine',
#    'movi',
#    'comedi',
#    'crime',
#    'action',
#    '&',
#    'adventur',
#    'action',
#    'comedi',
#    'mainland',
#    'chine',
#    'movi'],
#   ['Mandarin'],
#   'Movie',
#   ['Xinyun Li'],
#   ['Jiuwei Fan', ' Xun Lu'],
#   ['Hua Liu', ' You Zhou', ' Qianyuan Wang', ' Shanshan Yuan'],
#   '2018',
#   ['nab',
#    'drug',
#    'kingpin',
#    'four',
#    'cop',
#    'open',
#    'seafood',
#    'restaur',
#    'cover',
#    '.',
#    'must',
#    'seiz',
#    'chanc',
#    'secret',
#    'recip',
#    'turn',
#    'eateri',
#    'hit',
#    '.'],
#   0.63],
#  ['Magic hour',
#   ['crime'],
#   ['korean', 'movi', 'drama', 'independ', 'movi'],
#   ['English'],
#   'Movie',
#   ['Cole Mueller'],
#   ['Cole Mueller'],
#   ['Kris Lemche', ' C. Thomas Howell', ' Trevor Morgan', ' William Russ'],
#   'NaN',
#   ['receiv',
#    'grim',
#    'diagnosi',
#    'health',
#    'photograph',
#    'embark',
#    'journey',
#    'deliv',
#    'uncollect',
#    'photo',
#    'right',
#    'owner',
#    '.'],
#   0.66],
#  ['Marionette',
#   ['mysteri', 'thriller'],
#   ['korean', 'movi', 'thriller', 'movi', 'mysteri', 'crime', 'thriller'],
#   ['English'],
#   'Movie',
#   ['Elbert van Strien'],
#   ['Ben Hopkins', ' Elbert van Strien'],
#   ['Elijah Wolf', ' Sam Hazeldine', ' Thekla Reuten', ' Emun Elliott'],
#   '2020',
#   ['teacher',
#    'seek',
#    'former',
#    'detect',
#    'help',
#    'student',
#    'fall',
#    'victim',
#    'extortionist',
#    'blackmail',
#    'reveal',
#    'photo',
#    '14',
#    'year',
#    'ago',
#    '.'],
#   0.665],
#  ['Miss Baek',
#   ['drama'],
#   ['korean', 'movi', 'drama'],
#   ['Korean'],
#   'Movie',
#   ['Ji-won Lee'],
#   ['Ji-won Lee'],
#   ['Hee-joon Lee', ' Jun Suk-ho', ' Si-ah Kim', ' Han Ji-min'],
#   '2018',
#   ['remind',
#    'trauma',
#    'pain',
#    'past',
#    'upon',
#    'meet',
#    'young',
#    'girl',
#    'suffer',
#    'abus',
#    'ex-con',
#    'resolv',
#    'save',
#    'child',
#    'mother',
#    '.'],
#   0.725],
#  ['Old Marine Boy',
#   ['documentari'],
#   ['korean', 'movi', 'documentari', 'film'],
#   ['Korean'],
#   'Movie',
#   ['Mo-young Jin'],
#   ['nan'],
#   ['Myoungho Park', ' Cheolhoon Park', ' Cheoljoon Park', ' Soonhee Kim'],
#   'NaN',
#   ['documentari',
#    'plung',
#    'life',
#    'deep-sea',
#    'diver',
#    'put',
#    'life',
#    'oxygen',
#    'line',
#    'keep',
#    'famili',
#    'afloat',
#    'husband',
#    'father',
#    '.'],
#   0.7650000000000001],
#  ['Ordinary People',
#   ['drama'],
#   ['korean', 'movi', 'thriller', 'movi', 'crime', 'thriller'],
#   ['English'],
#   'Movie',
#   ['Robert Redford'],
#   ['Alvin Sargent', ' Judith Guest'],
#   ['Donald Sutherland',
#    ' Mary Tyler Moore',
#    ' Judd Hirsch',
#    ' Timothy Hutton'],
#   '1980',
#   ['dure',
#    'probe',
#    'miss',
#    'high',
#    'school',
#    'student',
#    'best',
#    'friend',
#    'new',
#    'gym',
#    'teacher',
#    'stumbl',
#    'upon',
#    'sinist',
#    'truth',
#    'behind',
#    'disappear',
#    '.'],
#   0.735],
#  ['Outdoor Begins',
#   ['comedi', 'fantasi', 'horror', 'thriller'],
#   ['korean', 'movi', 'comedi', 'horror', 'movi', 'horror', 'comedi'],
#   ['Korean'],
#   'Movie',
#   ['Jinseung Lim'],
#   ['Jinseung Lim', ' Min-suk Kang'],
#   ['Yoo-Mi Lee', ' Young-geun Hong', ' Deok-jae Jo', ' Song-Ha Yeon'],
#   '2017',
#   ['night',
#    'fall',
#    'primal',
#    'instinct',
#    'aris',
#    'cur',
#    'mask',
#    'turn',
#    'novic',
#    'hitman',
#    'sadist',
#    'murder',
#    'seclud',
#    'campsit',
#    '.'],
#   0.61],
#  ['Paths of the Soul',
#   ['drama'],
#   ['chine', 'movi', 'drama', 'mainland', 'chine', 'movi'],
#   ['Tibetan'],
#   'Movie',
#   ['Yang Zhang'],
#   ['Yang Zhang'],
#   ['Pei Yang', ' Tsring Chodron', ' Tsewang Dolkar', ' Jiangcuo Seba'],
#   '2017',
#   ['harsh',
#    'weather',
#    'unwav',
#    'devot',
#    'docudrama',
#    'follow',
#    'sever',
#    'villag',
#    'walk',
#    'pilgrimag',
#    'lhasa',
#    '—',
#    'holi',
#    'capit',
#    'tibet',
#    '.'],
#   0.87],
#  ['Promise at Dawn',
#   ['biographi', 'drama', 'romanc', 'war'],
#   ['movi',
#    'base',
#    'real',
#    'life',
#    'romant',
#    'drama',
#    'drama',
#    'romant',
#    'movi',
#    'movi',
#    'base',
#    'book',
#    'french'],
#   ['French', ' Polish', ' Spanish', ' English'],
#   'Movie',
#   ['Eric Barbier'],
#   ['Romain Gary', ' Eric Barbier', ' Marie Eynard'],
#   ['Pierre Niney',
#    ' Jean-Pierre Darroussin',
#    ' Didier Bourdon',
#    ' Charlotte Gainsbourg'],
#   '2019',
#   ['romain',
#    'rise',
#    'humbl',
#    'origin',
#    'becom',
#    'famous',
#    'writer',
#    'war',
#    'hero',
#    'fulfil',
#    'destini',
#    'set',
#    'well-mean',
#    'overbear',
#    'mother',
#    '.'],
#   0.73],
#  ['Rebel in the Rye',
#   ['biographi', 'drama', 'romanc', 'war'],
#   ['movi',
#    'base',
#    'real',
#    'life',
#    'drama',
#    'movi',
#    'base',
#    'book',
#    'u',
#    'movi'],
#   ['English'],
#   'Movie',
#   ['Danny Strong'],
#   ['Kenneth Slawenski', ' Danny Strong'],
#   ['Kevin Spacey', ' Nicholas Hoult', ' Victor Garber', ' Hope Davis'],
#   '2017',
#   ['young',
#    'j',
#    '.',
#    '.',
#    'saling',
#    'struggl',
#    'write',
#    'classic',
#    'novel',
#    '"',
#    'catcher',
#    'rye',
#    '"',
#    'tutelag',
#    'demand',
#    'mentor',
#    '.'],
#   0.435],
#  ['The Return',
#   ['drama'],
#   ['korean', 'movi', 'drama'],
#   ['Russian'],
#   'Movie',
#   ['Andrey Zvyagintsev'],
#   ['Vladimir Moiseenko', ' Aleksandr Novototskiy-Vlasov'],
#   ['Nataliya Vdovina',
#    ' Konstantin Lavronenko',
#    ' Ivan Dobronravov',
#    ' Vladimir Garin'],
#   '2003',
#   ['out-of-the-way',
#    'makgeolli',
#    'restaur',
#    'serv',
#    'rest',
#    'stop',
#    'long',
#    'heart',
#    'someon',
#    'may',
#    'may',
#    'return',
#    '.'],
#   0.6766666666666666],
#  ['The Rookies',
#   ['crime', 'drama'],
#   ['action',
#    '&',
#    'adventur',
#    'chine',
#    'movi',
#    'comedi',
#    'action',
#    'comedi',
#    'mainland',
#    'chine',
#    'movi'],
#   ['English'],
#   'Movie',
#   ['nan'],
#   ['William Blinn', ' Rita Lakin'],
#   ['Sam Melville',
#    ' Georg Stanford Brown',
#    " Gerald S. O'Loughlin",
#    ' Kate Jackson'],
#   '1972',
#   ['misunderstand',
#    'extrem',
#    'sport',
#    'enthusiast',
#    'recruit',
#    'elit',
#    'agent',
#    'head',
#    'danger',
#    'weapon',
#    'scheme',
#    'budapest',
#    '.'],
#   0.73],
#  ['Snatch Up',
#   ['drama', 'crime', 'action'],
#   ['korean', 'movi', 'thriller', 'movi', 'crime', 'thriller'],
#   ['English'],
#   'Movie',
#   ['Joon-Hyeong Heo'],
#   ['Joon-Hyeong Heo'],
#   ['Kwang-ryul Jun', ' Oh Jeong-Se', ' Kyeong-Yeong Lee', ' Mu-Yeol Kim'],
#   '2018',
#   ['job',
#    'seeker',
#    'politician',
#    'seven',
#    'men',
#    'various',
#    'walk',
#    'life',
#    'unexpect',
#    'join',
#    'chase',
#    'bag',
#    'money',
#    'claim',
#    '.'],
#   0.7],
#  ['Stray',
#   ['action', 'crime', 'fantasi', 'thriller'],
#   ['horror', 'movi', 'russian', 'movi', 'supernatur', 'horror', 'movi'],
#   ['English'],
#   'Movie',
#   ['Joe Sill'],
#   ['Alex Theurer', ' J.D. Dillard', ' Joe Sill'],
#   ['Karen Fukuhara', ' Christine Woods', ' Ross Partridge', ' Miyavi'],
#   '2019',
#   ['fill',
#    'void',
#    'left',
#    'disappear',
#    'son',
#    'coupl',
#    'adopt',
#    'feral',
#    'child',
#    'orphanag',
#    '–',
#    'choic',
#    'ha',
#    'dark',
#    'consequ',
#    '.'],
#   0.5775],
#  ['Stand by Me',
#   ['adventur', 'drama'],
#   ['korean', 'movi', 'drama'],
#   ['English'],
#   'Movie',
#   ['Rob Reiner'],
#   ['Bruce A. Evans', ' Stephen King', ' Raynold Gideon'],
#   ["Jerry O'Connell", ' Wil Wheaton', ' River Phoenix', ' Corey Feldman'],
#   '1986',
#   ['learn',
#    'immin',
#    'departur',
#    'life',
#    'grandfath',
#    'spend',
#    'final',
#    'day',
#    'prepar',
#    'part',
#    'gift',
#    'young',
#    'grandchild',
#    '.'],
#   0.72],
#  ['Tea Pets',
#   ['anim', 'adventur'],
#   ['child',
#    '&',
#    'famili',
#    'movi',
#    'chine',
#    'movi',
#    'comedi',
#    'famili',
#    'featur',
#    'famili',
#    'comedi',
#    'mainland',
#    'chine',
#    'movi'],
#   ['Chinese'],
#   'Movie',
#   ['Gary Wang'],
#   ['Gary Wang'],
#   ['Guanlin Ji', ' Jason Kesser'],
#   '2020',
#   ['group',
#    'cute',
#    'good-luck-charm',
#    'clay',
#    'figurin',
#    'break',
#    'mold',
#    'set',
#    'wild',
#    'wonder',
#    'adventur',
#    'encount',
#    'mysteri',
#    'entiti',
#    '.'],
#   0.665],
#  ['A Tiger In Winter',
#   ['drama', 'romanc'],
#   ['korean', 'movi', 'drama'],
#   ['Korean'],
#   'Movie',
#   ['Kwang-kuk Lee'],
#   ['Kwang-kuk Lee'],
#   ['Seung-gil Jeong', ' Hyun-Jung Go', ' Ye-eun Kim', ' Jin-wook Lee'],
#   '2018',
#   ['cusp',
#    'hit',
#    'rock',
#    'bottom',
#    'fail',
#    'writer',
#    'come',
#    'across',
#    'former',
#    'lover',
#    'novelist',
#    'midst',
#    'battl',
#    'woe',
#    '.'],
#   0.72],
#  ['The Three Little Pigs',
#   ['anim'],
#   ['child',
#    '&',
#    'famili',
#    'movi',
#    'chine',
#    'movi',
#    'anim',
#    'tale',
#    'comedi',
#    'action',
#    'comedi',
#    'famili',
#    'comedi',
#    'mainland',
#    'chine',
#    'movi'],
#   ['English'],
#   'Movie',
#   ['nan'],
#   ['Paul Leadon', ' Roddy Lee', ' Roz Phillips'],
#   ['Ric Herbert', ' Joanna Moore', ' Lee Perry'],
#   'NaN',
#   ['three',
#    'littl',
#    'pig',
#    'embark',
#    'new',
#    'adventur',
#    'use',
#    'kung',
#    'fu',
#    'skill',
#    'defeat',
#    'evil',
#    'wolf',
#    'help',
#    'guard',
#    'martial',
#    'art',
#    'treasur',
#    '.'],
#   0.685],
#  ['Wonderstruck',
#   ['adventur', 'drama', 'mysteri'],
#   ['child',
#    '&',
#    'famili',
#    'movi',
#    'action',
#    '&',
#    'adventur',
#    'drama',
#    'adventur',
#    'movi',
#    'base',
#    'book',
#    'mysteri',
#    'famili',
#    'featur',
#    'u',
#    'movi'],
#   ['English', ' Spanish'],
#   'Movie',
#   ['Todd Haynes'],
#   ['Brian Selznick'],
#   ['James Urbaniak',
#    ' Julianne Moore',
#    ' Millicent Simmonds',
#    ' Cory Michael Smith'],
#   '2017',
#   ['two',
#    'child',
#    'differ',
#    'era',
#    'embark',
#    'journey',
#    'self-discoveri',
#    'lead',
#    'new',
#    'york',
#    'citi',
#    'mysteri',
#    'bond',
#    'connect',
#    '.'],
#   0.5925],
#  ['Keys To The Heart',
#   ['comedi', 'drama', 'famili'],
#   ['korean', 'movi', 'comedi'],
#   ['Korean'],
#   'Movie',
#   ['Sung-Hyun Choi'],
#   ['Sung-Hyun Choi'],
#   ['Sung-ryung Kim', ' Jung-min Park', ' Lee Byung-Hun', ' Han Ji-min'],
#   '2018',
#   ['noth',
#    'common',
#    'mother',
#    'former',
#    'box',
#    'champion',
#    'music',
#    'savant',
#    'discov',
#    'brotherhood',
#    'dure',
#    'humor',
#    'cohabit',
#    '.'],
#   0.7866666666666667],
#  ['Intimate Strangers',
#   ['drama', 'romanc', 'thriller'],
#   ['korean', 'movi', 'comedi'],
#   ['French'],
#   'Movie',
#   ['Patrice Leconte'],
#   ['Jérôme Tonnerre', ' Patrice Leconte'],
#   ['Fabrice Luchini',
#    ' Sandrine Bonnaire',
#    ' Anne Brochet',
#    ' Michel Duchaussoy'],
#   '2004',
#   ['dinner',
#    'parti',
#    'longtim',
#    'friend',
#    'partner',
#    'play',
#    'game',
#    'share',
#    'everi',
#    'new',
#    'call',
#    'text',
#    'email',
#    'phone',
#    'entir',
#    'group',
#    '.'],
#   0.7274999999999999],
#  ['Homme Fatale',
#   ['comedi', 'histori', 'romanc'],
#   ['social', 'issu', 'drama', 'korean', 'movi', 'comedi', 'period', 'piec'],
#   ['Korean'],
#   'Movie',
#   ['Da-Jung Nam'],
#   ['Da-Jung Nam'],
#   ['Jisu Choi', ' Jun-Ho Lee', ' Jung So-Min', ' Gwi-hwa Choi'],
#   '2019',
#   ['effort',
#    'save',
#    'aunt',
#    'flail',
#    'busi',
#    'charm',
#    'bachelor',
#    'transform',
#    'first-ev',
#    'male',
#    'courtesan',
#    'entertain',
#    'ladi',
#    'joseon',
#    '.'],
#   0.7650000000000001],
#  ['Happy Bus Day',
#   ['comedi', 'drama'],
#   ['dark', 'comedi', 'korean', 'movi', 'comedi', 'independ', 'movi'],
#   ['Korean'],
#   'Movie',
#   ['Seung-Won Lee'],
#   ['nan'],
#   ['Ju-won Lee'],
#   '2017',
#   ['gather',
#    'celebr',
#    'birthday',
#    'oldest',
#    'son',
#    'famili',
#    'member',
#    'dark',
#    'secret',
#    'uncomfort',
#    'truth',
#    'reveal',
#    '.'],
#   0.76],
#  ['Gonjiam: Haunted Asylum',
#   ['horror'],
#   ['korean', 'movi', 'horror', 'movi', 'supernatur', 'horror', 'movi'],
#   ['Korean'],
#   'Movie',
#   ['Beom-sik Jeong'],
#   ['Sang-min Park', ' Beom-sik Jeong'],
#   ['Wi Ha-Joon', ' Seung-Wook Lee', ' Ye-Won Mun', ' Yoo Je-Yoon'],
#   '2018',
#   ['eager',
#    'captur',
#    'creepi',
#    'footag',
#    'web',
#    'seri',
#    'group',
#    'explor',
#    'ventur',
#    'abandon',
#    'infam',
#    'psychiatr',
#    'hospit',
#    '.'],
#   0.7233333333333333],
#  ['Golden Slumber',
#   ['action', 'drama', 'thriller'],
#   ['action',
#    '&',
#    'adventur',
#    'korean',
#    'movi',
#    'movi',
#    'base',
#    'book',
#    'action',
#    'thriller'],
#   ['Japanese'],
#   'Movie',
#   ['Yoshihiro Nakamura'],
#   ['Kôtarô Isaka'],
#   ['Yûko Takeuchi', ' Shihori Kanjiya', ' Nao Ohmori', ' Teruyuki Kagawa'],
#   '2010',
#   ['wrong',
#    'frame',
#    'presidenti',
#    'assassin',
#    'upstand',
#    'deliveri',
#    'man',
#    'forc',
#    'get',
#    'bottom',
#    'conspiraci',
#    'run',
#    '.'],
#   0.7566666666666667],
#  ['Extreme Job',
#   ['action', 'comedi', 'crime'],
#   ['dark',
#    'comedi',
#    'action',
#    '&',
#    'adventur',
#    'korean',
#    'movi',
#    'comedi',
#    'crime',
#    'action',
#    '&',
#    'adventur',
#    'action',
#    'comedi'],
#   ['Korean', ' Mandarin'],
#   'Movie',
#   ['Byeong-heon Lee'],
#   ['Se-yeong Bae'],
#   ['Lee Hanee', ' Shin Ha-kyun', ' Joon-seok Heo', ' Myoung Gong'],
#   '2019',
#   ['narcot',
#    'unit',
#    'take',
#    'restaur',
#    'near',
#    'gang',
#    'hideout',
#    'food',
#    'sold',
#    'keep',
#    'cover',
#    'turn',
#    'next',
#    'big',
#    'chicken',
#    'franchis',
#    '.'],
#   0.69],
#  ['Default',
#   ['drama'],
#   ['social', 'issu', 'drama', 'korean', 'movi', 'drama'],
#   ['Korean', ' English'],
#   'Movie',
#   ['Kook-Hee Choi'],
#   ['Seong-min Eom'],
#   ['Kim Hye-su', ' Yoo Ah-In', ' Woo-jin Jo', ' Joon-ho Huh'],
#   '2018',
#   ['1997',
#    'south',
#    'korea',
#    'oncom',
#    'econom',
#    'crisi',
#    'pose',
#    'dispar',
#    'challeng',
#    'bank',
#    'execut',
#    'financ',
#    'man',
#    'small',
#    'busi',
#    'owner',
#    '.'],
#   0.75],
#  ['Criticsized',
#   ['action', 'crime', 'drama', 'horror', 'thriller'],
#   ['psycholog',
#    'thriller',
#    'thriller',
#    'movi',
#    'crime',
#    'thriller',
#    'u',
#    'movi'],
#   ['English'],
#   'Movie',
#   ['Carl T. Evans'],
#   ['Renato Biribin Jr.', ' Carl T. Evans'],
#   ['James Kyson', ' Kerr Smith', ' Callum Blue', ' Mike Marino'],
#   '2016',
#   ['la',
#    'polic',
#    'detect',
#    'race',
#    'captur',
#    'serial',
#    'killer',
#    'target',
#    'film',
#    'critic',
#    'livestream',
#    'veng',
#    'spree',
#    'internet',
#    '.'],
#   0.3833333333333333],
#  ['Communication & Lies',
#   ['short', 'drama'],
#   ['korean', 'movi', 'drama', 'independ', 'movi'],
#   ['English'],
#   'Movie',
#   ['Christopher Banks'],
#   ['Christopher Banks', ' David Blakey'],
#   ['Alexander Campbell',
#    ' Rita Lefau Ryan',
#    ' Rudi Vodanovich',
#    ' Richard Lambeth'],
#   'NaN',
#   ['two',
#    'individu',
#    'trauma',
#    'past',
#    'find',
#    'ground',
#    'relationship',
#    'lie',
#    'hide',
#    'true',
#    'selv',
#    '.'],
#   0.62],
#  ['Clover',
#   ['comedi', 'crime', 'thriller'],
#   ['romant', 'drama', 'drama', 'romant', 'movi', 'japanes', 'movi'],
#   ['English'],
#   'Movie',
#   ['Jon Abrahams'],
#   ['Michael Testone'],
#   ['Mark Webber',
#    ' Nicole Elizabeth Berger',
#    ' Erika Christensen',
#    ' Jon Abrahams'],
#   '2020',
#   ['still',
#    'carri',
#    'torch',
#    'childhood',
#    'first',
#    'love',
#    '—',
#    'becom',
#    'famous',
#    'actor',
#    '—',
#    'saya',
#    'sudden',
#    'ask',
#    'handsom',
#    'aloof',
#    'bos',
#    '.'],
#   0.5166666666666667],
#  ['Blood Orange',
#   ['thriller'],
#   ['independ', 'movi', 'thriller', 'movi', 'british'],
#   ['English'],
#   'Movie',
#   ['Toby Tobias'],
#   ['Toby Tobias'],
#   ['Ben Lamb', ' Iggy Pop', ' Kacey Clarke', ' Antonio Magro'],
#   '2016',
#   ['veng',
#    'ex-lov',
#    'sudden',
#    'show',
#    'seclud',
#    'villa',
#    'age',
#    'rockstar',
#    'wife',
#    'fight',
#    'surviv',
#    'thing',
#    'spiral',
#    'control',
#    '.'],
#   0.36333333333333334],
#  ['The Big Shot',
#   ['crime', 'drama', 'film-noir', 'thriller'],
#   ['action',
#    '&',
#    'adventur',
#    'chine',
#    'movi',
#    'crime',
#    'action',
#    '&',
#    'adventur',
#    'mainland',
#    'chine',
#    'movi'],
#   ['English'],
#   'Movie',
#   ['Lewis Seiler'],
#   ['Bertram Millhauser', ' Abem Finkel', ' Daniel Fuchs'],
#   ['Susan Peters', ' Humphrey Bogart', ' Richard Travis', ' Irene Manning'],
#   '1942',
#   ['detect',
#    'investig',
#    'suicid',
#    'case',
#    'soon',
#    'uncov',
#    'greater',
#    'conspiraci',
#    'connect',
#    'real',
#    'estat',
#    'conglomer',
#    '.'],
#   0.7350000000000001],
#  ['Angels Time',
#   ['action', 'drama', 'fantasi', 'thriller'],
#   ['romant', 'drama', 'korean', 'movi', 'drama', 'romant', 'movi'],
#   ['English'],
#   'Movie',
#   ['nan'],
#   ['David Greenwalt', ' Joss Whedon'],
#   ['J. August Richards',
#    ' Alexis Denisof',
#    ' David Boreanaz',
#    ' Charisma Carpenter'],
#   '1999',
#   ['insid',
#    'hospit',
#    'meet',
#    'hope',
#    'blossom',
#    'alongsid',
#    'friendship',
#    'sick',
#    'high',
#    'school',
#    'student',
#    'athlet',
#    'need',
#    'surgeri',
#    '.'],
#   0.595],
#  ['After My Death',
#   ['drama'],
#   ['korean', 'movi', 'drama', 'independ', 'movi', 'mysteri'],
#   ['Korean'],
#   'Movie',
#   ['Kim Uiseok'],
#   ['Kim Uiseok'],
#   ['Taekyung Lee', ' Yeo-bin Jeon', ' Young-hwa Seo', ' Won-Hee Go'],
#   '2018',
#   ['suspicion',
#    'fall',
#    'follow',
#    'classmat',
#    'sudden',
#    'disappear',
#    'teenag',
#    'girl',
#    'forc',
#    'tri',
#    'prove',
#    'innoc',
#    '.'],
#   0.7150000000000001],
#  ['The Age of Blood',
#   ['action'],
#   ['action', '&', 'adventur', 'korean', 'movi', 'period', 'piec'],
#   ['Korean'],
#   'Movie',
#   ['Hong-sun Kim'],
#   ['nan'],
#   ['Seung-jin Hong', ' Su-a Hong', ' Jung Hae-In', ' Dan-bi Geum'],
#   '2017',
#   ['safeti',
#    'joseon',
#    'king',
#    'rest',
#    'shoulder',
#    'greatest',
#    'swordsman',
#    'catch',
#    'wind',
#    'assassin',
#    'plan',
#    'rebel',
#    'mastermind',
#    '.'],
#   0.6900000000000001],
#  ['The Accidental Detective 2: In Action',
#   ['comedi', 'crime', 'thriller'],
#   ['korean', 'movi', 'comedi', 'mysteri'],
#   ['Korean'],
#   'Movie',
#   ['Eon-hie Lee'],
#   ['Han-Jin Jung'],
#   ['Yeong-hie Seo', ' Sang-Woo Kwon', ' Dong-il Sung', ' Sung-je Cha'],
#   '2018',
#   ['newli',
#    'set',
#    'detect',
#    'agenc',
#    'two',
#    'privat',
#    'eye',
#    'team',
#    'eccentr',
#    'sleuth',
#    'uncov',
#    'answer',
#    'behind',
#    'string',
#    'untim',
#    'death',
#    '.'],
#   0.7333333333333334],
#  ['12 Feet Deep',
#   ['horror', 'thriller'],
#   ['horror', 'movi', 'u', 'movi'],
#   ['English'],
#   'Movie',
#   ['Matt Eskandari'],
#   ['Michael Hultquist', ' Matt Eskandari'],
#   ['Diane Farr',
#    ' Christian Kain Blackburn',
#    ' Nora-Jane Noone',
#    ' Alexandra Park'],
#   '2017',
#   ['estrang',
#    'sister',
#    'becom',
#    'trap',
#    'swim',
#    'pool',
#    'aquat',
#    'center',
#    'dure',
#    'long',
#    'holiday',
#    'weekend',
#    'lead',
#    'dark',
#    'famili',
#    'secret',
#    'reveal',
#    '.'],
#   0.41500000000000004],
#  ['1987: When the Day Comes',
#   ['drama'],
#   ['movi',
#    'base',
#    'real',
#    'life',
#    'social',
#    'issu',
#    'drama',
#    'korean',
#    'movi',
#    'drama'],
#   ['Korean'],
#   'Movie',
#   ['Joon-Hwan Jang'],
#   ['Kyung-chan Kim'],
#   ['Hae-Jin Yoo', ' Jung-woo Ha', ' Kim Yoon-seok', ' Kim Tae-ri'],
#   '2018',
#   ['truth',
#    'behind',
#    'cover-up',
#    'student',
#    'activist',
#    'death',
#    'govern',
#    'custodi',
#    'spark',
#    'movement',
#    'chang',
#    '.',
#    'inspir',
#    'true',
#    'event',
#    '.'],
#   0.77],
#  ['Enter the Fat Dragon',
#   ['action', 'comedi'],
#   ['action',
#    '&',
#    'adventur',
#    'chine',
#    'movi',
#    'comedi',
#    'action',
#    'comedi',
#    'hong',
#    'kong',
#    'movi'],
#   ['Cantonese', ' Japanese', ' English'],
#   'Movie',
#   ['Kenji Tanigaki', ' Aman Chang'],
#   ['Kin-Hung Chan', ' Jing Wong', ' Koon-Nam Lui'],
#   ['Jing Wong', ' Niki Chow', ' Teresa Mo', ' Donnie Yen'],
#   '2020',
#   ['cop',
#    'team',
#    'former',
#    'polic',
#    'inspector',
#    'restaur',
#    'owner',
#    'solv',
#    'mysteri',
#    'murder',
#    'soon',
#    'run',
#    'afoul',
#    'local',
#    'mob',
#    'tokyo',
#    '.'],
#   0.645],
#  ['Operation Buffalo',
#   ['adventur', 'comedi', 'drama', 'thriller', 'war'],
#   ['comedi', 'programm', 'drama', 'programm', 'australian', 'tv', 'programm'],
#   ['English', ' Aboriginal'],
#   'Series',
#   ['nan'],
#   ['nan'],
#   ['Tony Martin', ' Jessica De Gouw', ' James Cromwell', ' Ewen Leslie'],
#   '2020',
# ...
#    'target',
#    'famili',
#    'littl',
#    'boy',
#    'next',
#    'door',
#    '.'],
#   0.565],
#  ['The Professional',
#   ['action', 'crime', 'drama', 'thriller'],
#   ['action',
#    '&',
#    'adventur',
#    'movi',
#    'base',
#    'book',
#    'action',
#    'thriller',
#    'french',
#    'movi',
#    'action',
#    'movi'],
#   ['French'],
#   'Movie',
#   ['Georges Lautner'],
#   ['Georges Lautner',
#    ' Patrick Alexander',
#    ' Jacques Audiard',
#    ' Michel Audiard'],
#   ['Jean-Paul Belmondo',
#    ' Jean Desailly',
#    ' Marie-Christine Descouard',
#    ' Cyrielle Clair'],
#   '1981',
#   ['heâ€™',
#    'betray',
#    'govern',
#    'french',
#    'secret',
#    'agent',
#    'escap',
#    'captiv',
#    'return',
#    'home',
#    'retali',
#    'gave',
#    '.'],
#   0.65],
#  ['Zombillenium',
#   ['anim', 'comedi', 'famili', 'fantasi', 'horror'],
#   ['child',
#    '&',
#    'famili',
#    'film',
#    'comedi',
#    'horror',
#    'film',
#    'famili',
#    'featur',
#    'famili',
#    'comedi',
#    'zombi',
#    'horror',
#    'film'],
#   ['French'],
#   'Movie',
#   ['Arthur de Pins', ' Alexis Ducord'],
#   ['Arthur de Pins', ' Alexis Ducord'],
#   ['Kelly Marot', ' Emmanuel Curtil', ' Alexis Tomassian', ' Alain Choquet'],
#   '2017',
#   ['inspect',
#    'halloween',
#    'theme',
#    'park',
#    'safeti',
#    'offic',
#    'turn',
#    'zombi',
#    'soon',
#    'confront',
#    'class',
#    'tension',
#    'undead',
#    'communiti',
#    '.'],
#   0.71],
#  ['The Vultures',
#   ['action', 'comedi', 'drama', 'thriller', 'war'],
#   ['action',
#    '&',
#    'adventur',
#    'comedi',
#    'movi',
#    'base',
#    'book',
#    'action',
#    'comedi',
#    'french',
#    'movi',
#    'french',
#    'comedi'],
#   ['French', ' German'],
#   'Movie',
#   ['Henri Verneuil'],
#   ['Pierre Siniac', ' Henri Verneuil', ' Michel Audiard'],
#   ['Jean-Paul Belmondo',
#    ' Michel Constantin',
#    ' Jacques Villeret',
#    ' Michel Creton'],
#   '1984',
#   ['convoy',
#    'french',
#    'foreign',
#    'legion',
#    'sent',
#    'retriev',
#    'stash',
#    'gold',
#    'tunisia',
#    'get',
#    'caught',
#    'ambush',
#    'set',
#    'tug',
#    'war',
#    'treasur',
#    '.'],
#   0.675],
#  ['Love Is a Funny Thing',
#   ['comedi', 'drama', 'romanc'],
#   ['romant',
#    'drama',
#    'drama',
#    'romant',
#    'movi',
#    'french',
#    'drama',
#    'french',
#    'movi',
#    'romant',
#    'french',
#    'movi'],
#   ['French', ' English'],
#   'Movie',
#   ['Claude Lelouch'],
#   ['Pierre Uytterhoeven', ' Claude Pinoteau'],
#   ['Jean-Paul Belmondo',
#    ' Marcel Bozzuffi',
#    ' Maria Pia Conte',
#    ' Annie Girardot'],
#   '1969',
#   ['spous',
#    'back',
#    'home',
#    'french',
#    'actress',
#    'compos',
#    'take',
#    'romant',
#    'jaunt',
#    'across',
#    'america',
#    'chanc',
#    'meet',
#    'film',
#    'set',
#    'los',
#    'angel',
#    '.'],
#   0.71],
#  ['Le marginal',
#   ['action', 'crime', 'drama', 'thriller'],
#   ['action', '&', 'adventur', 'french', 'movi'],
#   ['French'],
#   'Movie',
#   ['Jacques Deray'],
#   ['Michel Audiard', ' Jean Herman', ' Jacques Deray'],
#   ['Jean-Paul Belmondo',
#    ' Carlos Sotto Mayor',
#    ' Henry Silva',
#    ' Pierre Vernier'],
#   '1983',
#   ['dead',
#    'battl',
#    'wit',
#    'ensu',
#    'single-mind',
#    'polic',
#    'detect',
#    'goe',
#    'drug-smuggl',
#    'kingpin',
#    'port',
#    'citi',
#    'marseill',
#    '.'],
#   0.665],
#  ['Le guignolo',
#   ['comedi', 'action'],
#   ['action',
#    '&',
#    'adventur',
#    'comedi',
#    'action',
#    'comedi',
#    'french',
#    'movi',
#    'french',
#    'comedi'],
#   ['French'],
#   'Movie',
#   ['Georges Lautner'],
#   ['Jean Herman', ' Michel Audiard'],
#   ['Jean-Paul Belmondo',
#    ' Von Gretchen Shepard',
#    ' Carla Romanelli',
#    ' Georges Géret'],
#   '1980',
#   ['smooth-talk',
#    'swindler',
#    'tri',
#    'evad',
#    'secret',
#    'agent',
#    'accident',
#    'seiz',
#    'mysteri',
#    'suitcas',
#    'contain',
#    'plan',
#    'valuabl',
#    'invent',
#    '.'],
#   0.47333333333333333],
#  ['Lincorrigible',
#   ['comedi', 'drama'],
#   ['comedi', 'movi', 'base', 'book', 'french', 'movi', 'french', 'comedi'],
#   ['Greek'],
#   'Movie',
#   ['Babis Makridis'],
#   ['Efthymis Filippou', ' Babis Makridis', ' George Giokas'],
#   ['Aris Servetalis',
#    ' Lefteris Matthaiou',
#    ' Makis Papadimitriou',
#    ' Nota Tserniafski'],
#   '2012',
#   ['charm',
#    'lovabl',
#    'compuls',
#    'liar',
#    'con',
#    'man',
#    'releas',
#    'prison',
#    'orchestr',
#    'sever',
#    'fraud',
#    'includ',
#    'scam',
#    'parol',
#    'offic',
#    '.'],
#   0.49000000000000005],
#  ['Hold-Up',
#   ['comedi', 'crime'],
#   ['comedi', 'movi', 'base', 'book', 'french', 'movi', 'french', 'comedi'],
#   ['English', ' French'],
#   'Movie',
#   ['Alexandre Arcady'],
#   ['Daniel Saint-Hamont',
#    ' Francis Veber',
#    ' Alexandre Arcady',
#    ' Jay Cronley'],
#   ['Jean-Paul Belmondo',
#    ' Jean-Pierre Marielle',
#    ' Kim Cattrall',
#    ' Guy Marchand'],
#   '1985',
#   ['witti',
#    'crook',
#    'dress',
#    'clown',
#    'take',
#    'hostag',
#    'dure',
#    'ingeni',
#    'montreal',
#    'bank',
#    'robberi',
#    '.',
#    'next',
#    'part',
#    'plan',
#    '–',
#    'escap',
#    '–',
#    'quick',
#    'unravel',
#    '.'],
#   0.5599999999999999],
#  ['Happy Easter',
#   ['comedi'],
#   ['comedi', 'french', 'movi', 'french', 'comedi'],
#   ['French'],
#   'Movie',
#   ['Georges Lautner'],
#   ['Jean Poiret'],
#   ['Jean-Paul Belmondo', ' Marie Laforêt', ' Rosy Varte', ' Sophie Marceau'],
#   '1984',
#   ['man',
#    'caught',
#    'wife',
#    'young',
#    'woman',
#    'claim',
#    'shes',
#    'daughter',
#    'prior',
#    'marriag',
#    '–',
#    'lie',
#    'quick',
#    'spin',
#    'tangl',
#    'web',
#    '.'],
#   0.6066666666666666],
#  ['Cop or Hood',
#   ['action', 'comedi', 'crime', 'drama', 'thriller'],
#   ['action',
#    '&',
#    'adventur',
#    'comedi',
#    'movi',
#    'base',
#    'book',
#    'action',
#    'comedi',
#    'french',
#    'movi',
#    'french',
#    'comedi'],
#   ['French'],
#   'Movie',
#   ['Georges Lautner'],
#   ['Michel Grisolia', ' Jean Herman', ' Michel Audiard'],
#   ['Jean-Paul Belmondo',
#    ' Claude Brosset',
#    ' Jean-François Balmer',
#    ' Georges Géret'],
#   '1979',
#   ['undercov',
#    'polic',
#    'commission',
#    'investig',
#    'corrupt',
#    'attempt',
#    'destroy',
#    'two',
#    'organ',
#    'crime',
#    'famili',
#    'nice',
#    'spark',
#    'war',
#    '.'],
#   0.6666666666666666],
#  ['City of Joy',
#   ['drama'],
#   ['social',
#    'issu',
#    'drama',
#    'drama',
#    'polit',
#    'drama',
#    'film',
#    'base',
#    'book'],
#   ['English'],
#   'Movie',
#   ['Roland Joffé'],
#   ['Dominique Lapierre', ' Mark Medoff'],
#   ['Shabana Azmi', ' Patrick Swayze', ' Pauline Collins', ' Om Puri'],
#   '1992',
#   ['american',
#    'doctor',
#    'outlook',
#    'forev',
#    'chang',
#    'cross',
#    'path',
#    'poverty-stricken',
#    'famili',
#    'clinic',
#    'volunt',
#    'calcutta',
#    'india',
#    '.'],
#   0.5766666666666668],
#  ['Cartouche',
#   ['action', 'comedi', 'adventur', 'drama'],
#   ['action',
#    '&',
#    'adventur',
#    'romant',
#    'comedi',
#    'comedi',
#    'romant',
#    'movi',
#    'action',
#    'comedi',
#    'french',
#    'movi',
#    'romant',
#    'french',
#    'movi',
#    'french',
#    'comedi'],
#   ['French'],
#   'Movie',
#   ['Philippe de Broca'],
#   ['Philippe de Broca', ' Daniel Boulanger', ' Charles Spaak'],
#   ['Jean-Paul Belmondo', ' Claudia Cardinale', ' Marcel Dalio', ' Jess Hahn'],
#   '1964',
#   ['son',
#    'barrel-mak',
#    'enlist',
#    'armi',
#    'escap',
#    'unwant',
#    'attent',
#    'local',
#    'gang',
#    '--',
#    'onli',
#    'join',
#    'leader',
#    'year',
#    'later',
#    '.'],
#   0.6333333333333334],
#  ['Body of My Enemy',
#   ['crime', 'drama', 'mysteri', 'thriller'],
#   ['social',
#    'issu',
#    'drama',
#    'drama',
#    'crime',
#    'movi',
#    'crime',
#    'drama',
#    'movi',
#    'base',
#    'book',
#    'mysteri',
#    'french',
#    'drama',
#    'french',
#    'movi'],
#   ['French'],
#   'Movie',
#   ['Henri Verneuil'],
#   ['Félicien Marceau', ' Henri Verneuil', ' Michel Audiard'],
#   ['Jean-Paul Belmondo',
#    ' Charles Gérard',
#    ' Bernard Blier',
#    ' Marie-France Pisier'],
#   '1976',
#   ['year',
#    'imprison',
#    'crime',
#    'didnt',
#    'commit',
#    'ex-convict',
#    'return',
#    'take',
#    'reveng',
#    'wealthi',
#    'patrician',
#    'famili',
#    'frame',
#    '.'],
#   0.7133333333333334],
#  ['Buffaloed',
#   ['comedi', 'drama'],
#   ['dark', 'comedi', 'comedi', 'independ', 'film'],
#   ['English'],
#   'Movie',
#   ['Tanya Wexler'],
#   ['Brian Sacca'],
#   ['Zoey Deutch', ' Jermaine Fowler', ' Jai Courtney', ' Judy Greer'],
#   '2020',
#   ['determin',
#    'flee',
#    'humdrum',
#    'hometown',
#    'buffalo',
#    'new',
#    'york',
#    'clever',
#    'hustler',
#    'peg',
#    'join',
#    'shadi',
#    'charact',
#    'seedi',
#    'busi',
#    'debt',
#    'collect',
#    '.'],
#   0.6649999999999999],
#  ['Ace of Aces',
#   ['adventur', 'comedi', 'sport'],
#   ['action',
#    '&',
#    'adventur',
#    'comedi',
#    'action',
#    'comedi',
#    'french',
#    'movi',
#    'french',
#    'comedi'],
#   ['German', ' French'],
#   'Movie',
#   ['Gérard Oury'],
#   ['Gérard Oury', ' Horst Wendlandt', ' Danièle Thompson'],
#   ['Jean-Paul Belmondo',
#    ' Rachid Ferrache',
#    ' Frank Hoffmann',
#    ' Marie-France Pisier'],
#   '1982',
#   ['former',
#    'world',
#    'war',
#    'pilot',
#    'compet',
#    'boxer',
#    '1936',
#    'olymp',
#    'berlin',
#    'help',
#    'smuggl',
#    'jewish',
#    'boy',
#    'famili',
#    'nazi',
#    'germani',
#    '.'],
#   0.7366666666666667],
#  ['Best of the Best',
#   ['action', 'drama', 'sport'],
#   ['action', '&', 'adventur', 'sport', 'film', 'martial', 'art', 'film'],
#   ['English'],
#   'Movie',
#   ['Robert Radler'],
#   ['Paul Levine', ' Phillip Rhee', ' Max Strom'],
#   ['James Earl Jones', ' Sally Kirkland', ' Eric Roberts', ' Phillip Rhee'],
#   '1989',
#   ['person',
#    'problem',
#    'racial',
#    'tension',
#    'distract',
#    'member',
#    'u',
#    '.',
#    '.',
#    'karat',
#    'team',
#    'handpick',
#    'compet',
#    'intern',
#    'martial',
#    'art',
#    'competit',
#    '.'],
#   0.47500000000000003],
#  ['1991',
#   ['comedi'],
#   ['film',
#    'base',
#    'real',
#    'life',
#    'comedi',
#    'independ',
#    'film',
#    'canadian',
#    'comedi',
#    'canadian',
#    'film',
#    'canadian',
#    'independ',
#    'film',
#    'critically-acclaim',
#    'canadian',
#    'film'],
#   ['French', ' Italian', ' English', ' German', ' Greek', ' Spanish'],
#   'Movie',
#   ['Ricardo Trogi'],
#   ['Ricardo Trogi'],
#   ['Claudio Colangelo',
#    ' Jean-Carl Boucher',
#    ' Sandrine Bisson',
#    ' Juliette Gosselin'],
#   '2018',
#   ['film',
#    'student',
#    'canada',
#    'decid',
#    'follow',
#    'love',
#    'life',
#    'itali',
#    'complic',
#    'quick',
#    'ensu',
#    '.'],
#   0.7649999999999999],
#  ['Space Brothers',
#   ['comedi'],
#   ['drama', 'anim', 'anim', 'seri', 'comedi', 'anim', 'anim', 'base', 'comic'],
#   ['Japanese'],
#   'Series',
#   ['Yoshitaka Mori'],
#   ['Chûya Koyama', ' Mika Ohmori'],
#   ['Buzz Aldrin', ' Kumiko Asô', ' Masaki Okada', ' Shun Oguri'],
#   '2012',
#   ['two',
#    'brother',
#    'vow',
#    'becom',
#    'astronaut',
#    'kid',
#    '.',
#    'younger',
#    'brother',
#    'hibito',
#    'join',
#    'nasa',
#    'older',
#    'brother',
#    'mutta',
#    'appli',
#    'go',
#    'space',
#    'jaxa',
#    '.'],
#   0.74],
#  ['Tower of God',
#   ['anim', 'action', 'adventur', 'drama', 'fantasi', 'mysteri'],
#   ['action', 'anim', 'anim', 'seri', 'sci-fi', '&', 'fantasi', 'anim'],
#   ['Japanese'],
#   'Series',
#   ['nan'],
#   ['nan'],
#   ['Matthew David Rudd',
#    ' Johnny Yong Bosch',
#    ' Cherami Leigh',
#    ' Chris Hackney'],
#   '2020',
#   ['say',
#    'everyth',
#    'top',
#    'tower',
#    '.',
#    'baam',
#    'climb',
#    'pursuit',
#    'dear',
#    'friend',
#    'rachel',
#    'ascend',
#    'ha',
#    'pas',
#    'test',
#    '.'],
#   0.765],
#  ['To The Abandoned Sacred Beasts',
#   ['anim', 'action', 'drama', 'fantasi', 'mysteri'],
#   ['drama',
#    'anim',
#    'action',
#    'anim',
#    'anim',
#    'seri',
#    'sci-fi',
#    '&',
#    'fantasi',
#    'anim',
#    'anim',
#    'base',
#    'comic'],
#   ['Japanese'],
#   'Series',
#   ['nan'],
#   ['nan'],
#   ['Kaito Ishikawa', ' Yôko Hikasa', ' Ray Chase', ' Saori Hayami'],
#   '2019',
#   ['civil',
#    'war',
#    'creat',
#    'ha',
#    'end',
#    ':',
#    'monstrous',
#    'super-soldi',
#    'call',
#    'incarn',
#    'must',
#    'adapt',
#    'peacetim',
#    'kill',
#    'beast',
#    'hunter',
#    '.'],
#   0.73],
#  ['Yashahime: Princess Half-Demon',
#   ['anim', 'action', 'adventur', 'comedi', 'fantasi'],
#   ['action',
#    'anim',
#    'anim',
#    'seri',
#    'sci-fi',
#    '&',
#    'fantasi',
#    'anim',
#    'anim',
#    'base',
#    'comic'],
#   ['Japanese'],
#   'Series',
#   ['nan'],
#   ['nan'],
#   ['Azusa Tadokoro',
#    ' Sara Matsumoto',
#    ' Mikako Komatsu',
#    ' Kôsuke Kobayashi'],
#   'NaN',
#   ['daughter',
#    'sesshomaru',
#    'inuyasha',
#    'travel',
#    'feudal',
#    'japan',
#    'present',
#    'day',
#    'search',
#    'memori',
#    'past',
#    'theyv',
#    'lost',
#    '.'],
#   0.81],
#  ['Rich Man',
#   ['comedi', 'romanc'],
#   ['tv', 'drama', 'romant', 'tv', 'drama', 'korean', 'tv', 'show'],
#   ['Korean'],
#   'Series',
#   ['nan'],
#   ['nan'],
#   ['Yeon-Soo Ha'],
#   '2018',
#   ['brilliant',
#    'ceo',
#    'rare',
#    'condit',
#    'prevent',
#    'recogn',
#    'face',
#    'hire',
#    'woman',
#    'photograph',
#    'memori',
#    'remind',
#    'ex',
#    '.'],
#   0.745],
#  ['Path of the Dragons',
#   ['nan'],
#   ['tv',
#    'drama',
#    'crime',
#    'tv',
#    'drama',
#    'tv',
#    'thriller',
#    'tv',
#    'show',
#    'base',
#    'book',
#    'japanes',
#    'tv',
#    'seri'],
#   ['Japanese'],
#   'Series',
#   ['nan'],
#   ['nan'],
#   ['Nao Honda', " Ken'ichi Endô", ' Yujiro Imamura', ' Yoshihiko Hosoda'],
#   '2020',
#   ['twin',
#    'brother',
#    'walk',
#    'veri',
#    'differ',
#    'path',
#    'life',
#    'come',
#    'togeth',
#    'bring',
#    'man',
#    'corpor',
#    'respons',
#    'death',
#    'parent',
#    '.'],
#   0.76],
#  ['Olympia Kyklos',
#   ['anim', 'comedi'],
#   ['tv', 'comedi'],
#   ['Japanese'],
#   'Series',
#   ['nan'],
#   ['nan'],
#   ['Jin Katagiri'],
#   'NaN',
#   ['short',
#    'burst',
#    'gag-heavi',
#    'mix',
#    'medium',
#    'anim',
#    'youth',
#    'ancient',
#    'greec',
#    'repeat',
#    'transport',
#    'tokyo',
#    '1964',
#    '—',
#    'year',
#    'olymp',
#    '.'],
#   0.75],
#  ['Moriarty the Patriot',
#   ['anim', 'crime', 'histori', 'mysteri', 'thriller'],
#   ['drama',
#    'anim',
#    'anim',
#    'seri',
#    'tv',
#    'thriller',
#    'histor',
#    'anim',
#    'anim',
#    'base',
#    'comic',
#    'mysteri',
#    '&',
#    'thriller',
#    'anim'],
#   ['Japanese'],
#   'Series',
#   ['nan'],
#   ['nan'],
#   ['Makoto Furukawa'],
#   '2020',
#   ['amidst',
#    '19th',
#    'centuri',
#    'england',
#    'stifl',
#    'inequ',
#    'william',
#    'jame',
#    'moriarti',
#    'plan',
#    'overturn',
#    'repress',
#    'class',
#    'system',
#    'creat',
#    'societi',
#    '.'],
#   0.815],
#  ['Im Standing on a Million Lives',
#   ['action', 'adventur', 'fantasi', 'sci-fi'],
#   ['action',
#    'anim',
#    'anim',
#    'seri',
#    'sci-fi',
#    '&',
#    'fantasi',
#    'anim',
#    'anim',
#    'base',
#    'comic'],
#   ['English', ' Sanskrit'],
#   'Series',
#   ['George Lucas'],
#   ['George Lucas'],
#   ['Liam Neeson', ' Ewan McGregor', ' Natalie Portman', ' Jake Lloyd'],
#   '1999',
#   ['transport',
#    'game-lik',
#    'dimens',
#    'along',
#    'two',
#    'classmat',
#    'junior',
#    'high',
#    'loner',
#    'yusuk',
#    'must',
#    'cooper',
#    'somehow',
#    'stay',
#    'aliv',
#    '.'],
#   0.49],
#  ['DRAGON QUEST The Adventure of Dai',
#   ['anim', 'action', 'adventur', 'fantasi'],
#   ['action',
#    'anim',
#    'anim',
#    'seri',
#    'kids&#39',
#    ';',
#    'tv',
#    'japanes',
#    'kids&#39',
#    ';',
#    'tv',
#    'kids&#39',
#    ';',
#    'anim',
#    'anim',
#    'base',
#    'video',
#    'game',
#    'anim',
#    'base',
#    'comic'],
#   ['Japanese'],
#   'Series',
#   ['nan'],
#   ['nan'],
#   ['Ai Furihata',
#    ' Mikako Komatsu',
#    ' Atsumi Tanezaki',
#    ' Toshiyuki Toyonaga'],
#   'NaN',
#   ['young',
#    'dai',
#    'embark',
#    'epic',
#    'journey',
#    'becom',
#    'legendari',
#    'hero',
#    'train',
#    'loyal',
#    'companion',
#    'save',
#    'world',
#    'resurrect',
#    'demon',
#    'king',
#    '.'],
#   0.85],
#  ['Double Fantasy',
#   ['drama'],
#   ['tv',
#    'drama',
#    'romant',
#    'tv',
#    'drama',
#    'steami',
#    'romanc',
#    'tv',
#    'show',
#    'base',
#    'book',
#    'japanes',
#    'tv',
#    'seri'],
#   ['Japanese'],
#   'Series',
#   ['nan'],
#   ['nan'],
#   ['Hidekazu Mashima', ' Ryô Ikeda', ' Asami Mizukawa', ' Zuimaro Awashima'],
#   '2018',
#   ['unsatisfi',
#    'seem',
#    'happi',
#    'marriag',
#    'success',
#    'scriptwrit',
#    'natsu',
#    'leav',
#    'husband',
#    'live',
#    'alon',
#    'citi',
#    'pursu',
#    'true',
#    'desir',
#    '.'],
#   0.78],
#  ...]

# %%
films.dtypes
# Out:
# Title                object
# Genre                object
# Tags                 object
# Languages            object
# Series or Movie    category
# Director             object
# Writer               object
# Actors               object
# Release Date         object
# Summary              object
# Average Score       float64
# dtype: object

# %% [markdown]
# Creating the index in Elasticsearch ([API](https://www.elastic.co/guide/en/elasticsearch/reference/current/indices-create-index.html)).

# %%
index_body = {
    'settings': {
        'number_of_shards': 1,
        'number_of_replicas': 1,
        
    },
    'mappings': {
          'properties': {
              'Title':{'type': 'integer'},
              'tweet': {'type': 'text'}  
          }
    }
}
