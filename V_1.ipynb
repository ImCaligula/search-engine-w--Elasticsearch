# %% [markdown]
# ## Loading Elasticsearch
#
# In this section Elasticsearch is installed on the colab machine and initialised. The scripts to be able to run it on Colab were provided by GitHub user [korakot](https://gist.github.com/korakot/15fe4f18d0e0f53d7b834ef797880500).

# %%
# !wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-7.0.0-linux-x86_64.tar.gz -q # it's an older version of Elasticsearch, latest release being 7.13.4, couldn't make it run with that
# !tar -xzf elasticsearch-7.0.0-linux-x86_64.tar.gz
# !chown -R daemon:daemon elasticsearch-7.0.0
# !pip install elasticsearch -q

# %%
import os
from subprocess import Popen, PIPE, STDOUT

# %% [markdown]
# This cell runs Elasticsearch in the hosted runtime machine.

# %%
es_server = Popen(['elasticsearch-7.0.0/bin/elasticsearch'], 
                  stdout=PIPE, stderr=STDOUT,
                  preexec_fn=lambda: os.setuid(1)  # as daemon
                 )

# %% [markdown]
# The next command is using [cURL](https://curl.se/), which is used as a REST API to communicate with the Elasticsearch client. In this case it is adapting te request in query DSL (Elasticsearch's proprietary language). It's just checking if Elasticsearch is running locally (in the google machine in this case) by querying its default port (`localhost:9200`)

# %%
# !curl -X GET "localhost:9200/"
# Out:
# {
#   "name" : "d5c51a4a5492",
#   "cluster_name" : "elasticsearch",
#   "cluster_uuid" : "EFIdN210QWO4SY_U-OHaaQ",
#   "version" : {
#     "number" : "7.0.0",
#     "build_flavor" : "default",
#     "build_type" : "tar",
#     "build_hash" : "b7e28a7",
#     "build_date" : "2019-04-05T22:55:32.697037Z",
#     "build_snapshot" : false,
#     "lucene_version" : "8.0.0",
#     "minimum_wire_compatibility_version" : "6.7.0",
#     "minimum_index_compatibility_version" : "6.0.0-beta1"
#   },
#   "tagline" : "You Know, for Search"
# }

# %%
from elasticsearch import Elasticsearch

# %%
es = Elasticsearch()
es.ping() # another way to test whether ES is running, returns True if so
# Out:
# True

# %% [markdown]
# Elasticsearch should be running fine. Before creating an index, it is worth it to preprocess the data.
#
# ## Preprocessing

# %%
import pandas as pd
import numpy as np
import nltk
import re
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Next cell loads the dataset. It is available on [Kaggle](https://www.kaggle.com/ashishgup/netflix-rotten-tomatoes-metacritic-imdb), it is currently being updated to the local runtime directly as using code to download it directly requires a personal Kaggle API  token.

# %%
films = pd.read_csv("netflix-rotten-tomatoes-metacritic-imdb.csv")
films.head()
# Out:
#                  Title  ... Trailer Site
# 0     Lets Fight Ghost  ...          NaN
# 1  HOW TO BUILD A GIRL  ...      YouTube
# 2           Centigrade  ...      YouTube
# 3                ANNE+  ...          NaN
# 4                Moxie  ...          NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# The next cell contains the preprocessing functions.

# %%
def query_processor(query):
    query = re.sub(r"(\w)([.,;:!?'\"”\)])", r"\1 \2", query)
    query = re.sub(r"([.,;:!?'\"“\(])(\w)", r"\1 \2", query)
    query = re.sub("'", "", query)
    query = re.sub(",", "", query)
    tokens = re.split(r"\s+",query)
    tokens = [t.lower() for t in tokens]
    # Stemming with the SnowballStemmer for more efficiency
    s_stemmer = SnowballStemmer("english")
    stemedList = []
    for word in tokens:
        stemedList.append(s_stemmer.stem(word))
    tokens = stemedList
    # Lemmatising the tokens
    wordnet_lemmatiser = WordNetLemmatizer()
    lemmaList = []
    for word in stemedList:
        lemmaList.append(wordnet_lemmatiser.lemmatize(word))
    tokens = lemmaList
    # Finally remove stopwords
    stops = set(stopwords.words("english"))
    tokens = [word for word in tokens if not word in stops]
    return tokens

def dataset_processor(dataset):
    dataset = pd.read_csv("netflix-rotten-tomatoes-metacritic-imdb.csv")
    dataset = dataset.drop(columns = ["Trailer Site", "TMDb Trailer", "Poster", "Image", "IMDb Votes", "Netflix Link", "Production House", "Netflix Release Date", "Boxoffice", "Awards Received", "Awards Nominated For", "IMDb Link", "Runtime", "Country Availability", "View Rating"])
    dataset["Average Score"] = dataset.apply(Average, axis = 1)
    dataset = dataset.drop(columns = ["Hidden Gem Score", "IMDb Score", "Rotten Tomatoes Score", "Metacritic Score"])
    dataset = dataset.astype({"Title":"str", "Genre":"str", "Tags":"str",
                     "Languages":"str", "Series or Movie":"category",
                     "Director":"str", "Writer":"str", "Actors":"str",
                     "Summary":"str", "Average Score":"float"})
    # So need to query processor the summary, genre list and tag list.
    for i in ["Summary", "Genre", "Tags"]:
      dataset[i] = dataset.loc[:, i].apply(query_processor)

    # Need to turn the director, writer, languages, and actors into a list.
    for i in ["Director", "Languages", "Writer", "Actors"]:
      dataset[i] = dataset.loc[:,i].apply(Split)

    # Change the release data to just the year
    dataset["Release Date"] = dataset["Release Date"].apply(Year)
    return dataset

def Split(row):
  tokens = re.split(",", row)
  return tokens

def Year(row):
  tokens = re.split(" ", str(row))
  if tokens[0] == "nan":
    return "NaN"
  else:
    return tokens[2]

def Average(row):
  scores = []
  scorers = ["Hidden Gem Score", "IMDb Score", "Rotten Tomatoes Score", "Metacritic Score"]
  potential = [10,10,100,100]
  for i in range(len(scorers)):
    if (np.isnan(row.loc[scorers[i]])) == False:
      scores.append(row.loc[scorers[i]]/potential[i])
  if len(scores) > 0:
    return sum(scores)/len(scores)
  else:
    return "NaN"

# %%
# preprocessing the dataset
films = dataset_processor(films)
films.head()
# Out:
#                  Title  ... Average Score
# 0     Lets Fight Ghost  ...         0.755
# 1  HOW TO BUILD A GIRL  ...         0.690
# 2           Centigrade  ...         0.510
# 3                ANNE+  ...         0.710
# 4                Moxie  ...         0.720
#
# [5 rows x 11 columns]

# %%
films[films['Average Score'].isna()]
# Out:
#                                  Title  ... Average Score
# 208                      The Strongest  ...           NaN
# 220                       Firefly Lane  ...           NaN
# 246                         Le Tournoi  ...           NaN
# 248                        She is King  ...           NaN
# 249        How to Eliminate My Teacher  ...           NaN
# ...                                ...  ...           ...
# 15471         DreamWorks Short Stories  ...           NaN
# 15472         DreamWorks Shrek Stories  ...           NaN
# 15474            Nijntje and Vriendjes  ...           NaN
# 15475           K-POP Extreme Survival  ...           NaN
# 15476  DreamWorks Shreks Swamp Stories  ...           NaN
#
# [2086 rows x 11 columns]

# %%
films.dropna(subset=['Average Score'], inplace=True)

films[films['Average Score'].isna()]
# Out:
# Empty DataFrame
# Columns: [Title, Genre, Tags, Languages, Series or Movie, Director, Writer, Actors, Release Date, Summary, Average Score]
# Index: []

# %% [markdown]
# ## Indexing the documents

# %%
film_list = films.values.tolist()

# %%
films.dtypes
# Out:
# Title                object
# Genre                object
# Tags                 object
# Languages            object
# Series or Movie    category
# Director             object
# Writer               object
# Actors               object
# Release Date         object
# Summary              object
# Average Score       float64
# dtype: object

# %% [markdown]
# Creating the index in Elasticsearch ([API](https://www.elastic.co/guide/en/elasticsearch/reference/current/indices-create-index.html)).

# %%
index_body = {
    'settings': {
        'number_of_shards': 1,
        'number_of_replicas': 1,
        
    },
    'mappings': {
          'properties': {
              'Title': {'type': 'text'},
              'Genre': {'type': 'keyword'},
              'Tags' : {'type': 'keyword'},
              'Languages': {'type': 'keyword'},
              'Series or Movie' : {'type' : 'keyword'},
              'Director' : {'type': 'text'},
              'Writer' : {'type': 'text'},
              'Actors' : {'type': 'text'},
              'Release Date' : {'type': 'integer'},
              'Summary' : {'type': 'text'},
              'Average Score' : {'type': 'double'}  
          }
    }
}

# %%
index_name = 'netflix'

# es.indices.delete(index='netflix', ignore=[400, 404]) # useful during development to reset the index
es.indices.create(index_name, body=index_body)
# Out:
# {'acknowledged': True, 'index': 'netflix', 'shards_acknowledged': True}

# %%
for title, genre, tags, languages, series_or_movie, director, writer, actors, release_date, summary, avg_score in film_list:
  list_body = {
      'Title': title,
      'Genre': genre,
      'Tags' : tags,
      'Languages': languages,
      'Series or Movie' : series_or_movie,
      'Director' : director,
      'Writer' : writer,
      'Actors' : actors,
      'Release Date' : release_date,
      'Summary' : summary,
      'Average Score' : avg_score
  }
  es.index(index_name, list_body)

# %%
es.cat.count(index='netflix',h=['count'])
# Out:
# '13394\n'

# %%
es.search(index="netflix", body={"query": {"match_all": {}}})
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': 'kN6t3noBRRNrcnq56zWl',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Tim Roth',
#       ' Amanda Plummer',
#       ' Laura Lovelace',
#       ' John Travolta'],
#      'Average Score': 0.8025,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['crime', 'drama'],
#      'Languages': ['English', ' Spanish', ' French'],
#      'Release Date': '1994',
#      'Series or Movie': 'Movie',
#      'Summary': ['shelter',
#       'young',
#       'woman',
#       'becom',
#       'enamor',
#       'struggl',
#       'writer',
#       'goe',
#       'great',
#       'length',
#       'becom',
#       'involv',
#       'creativ',
#       'process',
#       '.'],
#      'Tags': ['psycholog',
#       'thriller',
#       'independ',
#       'film',
#       'thriller',
#       'indonesian',
#       'film'],
#      'Title': 'Fiction.',
#      'Writer': ['Quentin Tarantino', ' Roger Avary']},
#     '_type': '_doc'},
#    {'_id': 'kd6t3noBRRNrcnq56zW1',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Faizal Abdullah',
#       ' Fatin Amira',
#       ' Juliette Binoche',
#       ' Aric Hidir Amin'],
#      'Average Score': 0.735,
#      'Director': ['K Rajagopal',
#       ' Royston Tan',
#       ' Kelvin Tong',
#       ' Junfeng Boo',
#       ' Jack Neo',
#       ' Pin Pin Tan',
#       ' Eric Khoo'],
#      'Genre': ['drama'],
#      'Languages': ['English', ' Malay', ' Hokkien', ' Mandarin', ' Malayalam'],
#      'Release Date': '2015',
#      'Series or Movie': 'Movie',
#      'Summary': ['antholog',
#       'short',
#       'acclaim',
#       'filmmak',
#       'embrac',
#       'cultur',
#       'histori',
#       'singapor',
#       'celebr',
#       'countri',
#       'golden',
#       'jubile',
#       '.'],
#      'Tags': ['drama', 'singaporean', 'movi'],
#      'Title': '7 Letters',
#      'Writer': ['K Rajagopal',
#       ' Royston Tan',
#       ' Kelvin Tong',
#       ' Ivan Ho',
#       ' Junfeng Boo',
#       ' Jack Neo',
#       ' Pin Pin Tan',
#       ' Eric Khoo']},
#     '_type': '_doc'},
#    {'_id': 'kt6t3noBRRNrcnq56zXA',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Dan Stevens',
#       ' Brendan Meyer',
#       ' Maika Monroe',
#       ' Sheila Kelley'],
#      'Average Score': 0.6825000000000001,
#      'Director': ['Adam Wingard'],
#      'Genre': ['action', 'mysteri', 'thriller'],
#      'Languages': ['English'],
#      'Release Date': '2014',
#      'Series or Movie': 'Series',
#      'Summary': ['bound',
#       'togeth',
#       'tragic',
#       'past',
#       'psychic',
#       'priest',
#       'detect',
#       'join',
#       'forc',
#       'take',
#       'power',
#       'spirit',
#       'driven',
#       'bloodthirst',
#       '.'],
#      'Tags': ['tv',
#       'mysteri',
#       'korean',
#       'tv',
#       'show',
#       'tv',
#       'horror',
#       'tv',
#       'thriller',
#       'tv',
#       'show',
#       'base',
#       'book'],
#      'Title': 'The Guest',
#      'Writer': ['Simon Barrett']},
#     '_type': '_doc'},
#    {'_id': 'k96t3noBRRNrcnq56zXM',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Zoe Axelrod',
#       ' David Cross',
#       ' Shelley Berman',
#       ' Michael Chiklis'],
#      'Average Score': 0.47,
#      'Director': ['Steve Trenbirth'],
#      'Genre': ['anim', 'famili', 'fantasi'],
#      'Languages': ['English'],
#      'Release Date': '2019',
#      'Series or Movie': 'Movie',
#      'Summary': ['young',
#       'boy',
#       'discov',
#       'magic',
#       'power',
#       'learn',
#       'onli',
#       'hope',
#       'protect',
#       'mythic',
#       'land',
#       'save',
#       'famili',
#       'evil',
#       'power',
#       'uncl',
#       '.'],
#      'Tags': ['child',
#       '&',
#       'famili',
#       'movi',
#       'famili',
#       'sci-fi',
#       '&',
#       'fantasi',
#       'famili',
#       'adventur'],
#      'Title': 'The Legend of Secret Pass',
#      'Writer': ['Erik Shein', ' James Costello', ' Karl Geurs']},
#     '_type': '_doc'},
#    {'_id': 'lN6t3noBRRNrcnq56zXX',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Geena Davis',
#       ' Common',
#       ' Jessica Chastain',
#       ' John Malkovich'],
#      'Average Score': 0.3866666666666667,
#      'Director': ['Tate Taylor'],
#      'Genre': ['action', 'crime', 'drama', 'thriller'],
#      'Languages': ['English', ' German', ' French', ' Chinese'],
#      'Release Date': '2020',
#      'Series or Movie': 'Movie',
#      'Summary': ['elit',
#       'assassin',
#       'wrestl',
#       'doubt',
#       'work',
#       'scrambl',
#       'protect',
#       '—',
#       'estrang',
#       'famili',
#       '—',
#       'hit',
#       'goe',
#       'danger',
#       'wrong',
#       '.'],
#      'Tags': ['action',
#       '&',
#       'adventur',
#       'action',
#       'thriller',
#       'action',
#       'movi'],
#      'Title': 'Ava',
#      'Writer': ['Matthew Newton']},
#     '_type': '_doc'},
#    {'_id': 'ld6t3noBRRNrcnq56zXh',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ["Sean O'Bryan",
#       ' Hermione Corfield',
#       ' Jay Paulson',
#       ' Micah Hauptman'],
#      'Average Score': 0.63,
#      'Director': ['Jen McGowan'],
#      'Genre': ['crime', 'drama', 'thriller'],
#      'Languages': ['English'],
#      'Release Date': '2020',
#      'Series or Movie': 'Movie',
#      'Summary': ['wrong',
#       'turn',
#       'wood',
#       'becom',
#       'fight',
#       'life',
#       'career-seek',
#       'colleg',
#       'student',
#       'run',
#       'two',
#       'outlaw',
#       'brother',
#       'look',
#       'cook',
#       'troubl',
#       '.'],
#      'Tags': ['thriller',
#       'movi',
#       'thriller',
#       'movi',
#       'crime',
#       'thriller',
#       'crime',
#       'thriller'],
#      'Title': 'Rust Creek',
#      'Writer': ['Julie Lipson', ' Stu Pollard']},
#     '_type': '_doc'},
#    {'_id': 'lt6t3noBRRNrcnq56zXq',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Lexi Simonsen',
#       ' Ryan Phillippe',
#       ' Casper Van Dien',
#       ' Jack Griffo'],
#      'Average Score': 0.43,
#      'Director': ['Brian Skiba'],
#      'Genre': ['action', 'drama'],
#      'Languages': ['English'],
#      'Release Date': '2020',
#      'Series or Movie': 'Movie',
#      'Summary': ['secret',
#       'servic',
#       'agent',
#       'drawn',
#       'terrorist',
#       'plot',
#       'son',
#       'classmat',
#       'daughter',
#       'suprem',
#       'court',
#       'justic',
#       'target',
#       'kidnap',
#       '.'],
#      'Tags': ['action', '&', 'adventur'],
#      'Title': 'The 2nd',
#      'Writer': ['James Bromberg', ' Paul Taegel', ' Eric Bromberg']},
#     '_type': '_doc'},
#    {'_id': 'l96t3noBRRNrcnq56zX0',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Sue Ramirez',
#       ' Jelson Bay',
#       ' Roxanne Guinoo',
#       ' Sandy Andolong'],
#      'Average Score': 0.6,
#      'Director': ['Marla Ancheta'],
#      'Genre': ['drama'],
#      'Languages': ['Filipino', ' English'],
#      'Release Date': '2020',
#      'Series or Movie': 'Movie',
#      'Summary': ['emot',
#       'journey',
#       'morocco',
#       'entrepreneur',
#       'piec',
#       'togeth',
#       'turbul',
#       'life',
#       'estrang',
#       'mother',
#       'meet',
#       'adopt',
#       'daughter',
#       '.'],
#      'Tags': ['drama', 'filipino', 'film'],
#      'Title': 'Finding Agnes',
#      'Writer': ['Aileen Alcampado Kessop']},
#     '_type': '_doc'},
#    {'_id': 'mN6t3noBRRNrcnq56zX9',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Richard Short',
#       ' Bart Edwards',
#       ' Alexandra Evans',
#       ' Richard Brake'],
#      'Average Score': 0.6000000000000001,
#      'Director': ['Giles Alderson'],
#      'Genre': ['horror', 'mysteri', 'thriller'],
#      'Languages': ['English'],
#      'Release Date': '2020',
#      'Series or Movie': 'Movie',
#      'Summary': ['stori',
#       'child',
#       'prank',
#       'gone',
#       'wrong',
#       'past',
#       'four',
#       'kidnap',
#       'stranger',
#       'present',
#       'becom',
#       'intertwin',
#       'gori',
#       'horror',
#       'thriller',
#       '.'],
#      'Tags': ['independ', 'movi', 'horror', 'movi', 'british', 'movi'],
#      'Title': 'The Dare',
#      'Writer': ['Giles Alderson', ' Jonny Grant']},
#     '_type': '_doc'},
#    {'_id': 'md6t3noBRRNrcnq57DUH',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Valeria Golino',
#       ' Francesco Casisa',
#       ' Vincenzo Amato',
#       " Veronica D'Agostino"],
#      'Average Score': 0.6849999999999999,
#      'Director': ['Emanuele Crialese'],
#      'Genre': ['drama'],
#      'Languages': ['Italian', ' Sicilian'],
#      'Release Date': '2002',
#      'Series or Movie': 'Movie',
#      'Summary': ['nan'],
#      'Tags': ['drama', 'comedi', 'italian', 'movi'],
#      'Title': 'Respiro',
#      'Writer': ['Emanuele Crialese']},
#     '_type': '_doc'}],
#   'max_score': 1.0,
#   'total': {'relation': 'gte', 'value': 10000}},
#  'timed_out': False,
#  'took': 7}

# %%
es.search(index="netflix", body={"query":{'term': {'Genre' : 'crime'}} })

# %%
es.search(index="netflix", body={"query":{'match': {'Director' : 'Tarantino'}} })
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': 'kN6t3noBRRNrcnq56zWl',
#     '_index': 'netflix',
#     '_score': 7.3616014,
#     '_source': {'Actors': ['Tim Roth',
#       ' Amanda Plummer',
#       ' Laura Lovelace',
#       ' John Travolta'],
#      'Average Score': 0.8025,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['crime', 'drama'],
#      'Languages': ['English', ' Spanish', ' French'],
#      'Release Date': '1994',
#      'Series or Movie': 'Movie',
#      'Summary': ['shelter',
#       'young',
#       'woman',
#       'becom',
#       'enamor',
#       'struggl',
#       'writer',
#       'goe',
#       'great',
#       'length',
#       'becom',
#       'involv',
#       'creativ',
#       'process',
#       '.'],
#      'Tags': ['psycholog',
#       'thriller',
#       'independ',
#       'film',
#       'thriller',
#       'indonesian',
#       'film'],
#      'Title': 'Fiction.',
#      'Writer': ['Quentin Tarantino', ' Roger Avary']},
#     '_type': '_doc'},
#    {'_id': 'ud6u3noBRRNrcnq5Oj2_',
#     '_index': 'netflix',
#     '_score': 7.3616014,
#     '_source': {'Actors': ['Margot Robbie',
#       ' Brad Pitt',
#       ' Leonardo DiCaprio',
#       ' Emile Hirsch'],
#      'Average Score': 0.7125,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['comedi', 'drama'],
#      'Languages': ['English', ' Italian', ' Spanish', ' German'],
#      'Release Date': '2019',
#      'Series or Movie': 'Movie',
#      'Summary': ['1969',
#       '.',
#       'tv',
#       'actor',
#       'stunt-doubl',
#       'friend',
#       'weigh',
#       'next',
#       'move',
#       'la',
#       'rock',
#       'chang',
#       'scene',
#       'hottest',
#       'coupl',
#       'arriv',
#       'next',
#       'door',
#       '.'],
#      'Tags': ['drama', 'u', 'movi', 'comedi'],
#      'Title': 'Once Upon a Time in Hollywood',
#      'Writer': ['Quentin Tarantino']},
#     '_type': '_doc'},
#    {'_id': 'GN6u3noBRRNrcnq5fEUb',
#     '_index': 'netflix',
#     '_score': 7.3616014,
#     '_source': {'Actors': ['Walton Goggins',
#       ' Samuel L. Jackson',
#       ' Jennifer Jason Leigh',
#       ' Kurt Russell'],
#      'Average Score': 0.6425,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['crime', 'drama', 'mysteri', 'thriller', 'western'],
#      'Languages': ['English', ' Spanish', ' French'],
#      'Release Date': '2015',
#      'Series or Movie': 'Series',
#      'Summary': ['trap',
#       'stagecoach',
#       'stop',
#       'storm',
#       'rage',
#       'outsid',
#       'two',
#       'bounti',
#       'hunter',
#       'outlaw',
#       'face',
#       'galleri',
#       'rogu',
#       '.',
#       'featur',
#       'never-before-seen',
#       'footag',
#       '.'],
#      'Tags': ['western', 'thriller', 'crime', 'thriller'],
#      'Title': 'The Hateful Eight: Extended Version',
#      'Writer': ['Quentin Tarantino']},
#     '_type': '_doc'},
#    {'_id': 'jN6v3noBRRNrcnq5Glco',
#     '_index': 'netflix',
#     '_score': 7.3616014,
#     '_source': {'Actors': ['Walton Goggins',
#       ' Samuel L. Jackson',
#       ' Jennifer Jason Leigh',
#       ' Kurt Russell'],
#      'Average Score': 0.6425,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['crime', 'drama', 'mysteri', 'thriller', 'western'],
#      'Languages': ['English', ' Spanish', ' French'],
#      'Release Date': '2015',
#      'Series or Movie': 'Movie',
#      'Summary': ['year',
#       'civil',
#       'war',
#       'bounti',
#       'hunter',
#       'captiv',
#       'waylaid',
#       'wyom',
#       'blizzard',
#       'hole',
#       'way',
#       'station',
#       'six',
#       'dicey',
#       'stranger',
#       '.'],
#      'Tags': ['adventur',
#       'action',
#       '&',
#       'adventur',
#       'period',
#       'piec',
#       'western',
#       'crime',
#       'movi',
#       'thriller',
#       'movi',
#       'crime',
#       'thriller'],
#      'Title': 'The Hateful Eight',
#      'Writer': ['Quentin Tarantino']},
#     '_type': '_doc'},
#    {'_id': 'it6v3noBRRNrcnq5e2Jk',
#     '_index': 'netflix',
#     '_score': 7.3616014,
#     '_source': {'Actors': ['Jamie Foxx',
#       ' Christoph Waltz',
#       ' Kerry Washington',
#       ' Leonardo DiCaprio'],
#      'Average Score': 0.7350000000000001,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['drama', 'western'],
#      'Languages': ['English', ' German', ' French', ' Italian'],
#      'Release Date': '2012',
#      'Series or Movie': 'Movie',
#      'Summary': ['accompani',
#       'german',
#       'bounti',
#       'hunter',
#       'freed',
#       'slave',
#       'name',
#       'django',
#       'travel',
#       'across',
#       'america',
#       'free',
#       'wife',
#       'sadist',
#       'plantat',
#       'owner',
#       '.'],
#      'Tags': ['drama',
#       'western',
#       'period',
#       'piec',
#       'action',
#       '&',
#       'adventur',
#       'crime',
#       'action',
#       '&',
#       'adventur',
#       'crime',
#       'drama',
#       'social',
#       'issu',
#       'drama',
#       'crime',
#       'film',
#       'u',
#       'movi',
#       'award-win',
#       'drama'],
#      'Title': 'Django Unchained',
#      'Writer': ['Quentin Tarantino']},
#     '_type': '_doc'},
#    {'_id': '1d6v3noBRRNrcnq5hmNv',
#     '_index': 'netflix',
#     '_score': 7.3616014,
#     '_source': {'Actors': ['Mélanie Laurent',
#       ' Brad Pitt',
#       ' Christoph Waltz',
#       ' Eli Roth'],
#      'Average Score': 0.7025,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['adventur', 'drama', 'war'],
#      'Languages': ['English', ' German', ' French', ' Italian'],
#      'Release Date': '2009',
#      'Series or Movie': 'Movie',
#      'Summary': ['jewish',
#       'cinema',
#       'owner',
#       'occupi',
#       'pari',
#       'forc',
#       'host',
#       'nazi',
#       'premier',
#       'group',
#       'american',
#       'soldier',
#       'call',
#       'basterd',
#       'plan',
#       'face-off',
#       '.'],
#      'Tags': ['action',
#       'thriller',
#       'militari',
#       'action',
#       '&',
#       'adventur',
#       'spi',
#       'action',
#       '&',
#       'adventur',
#       'action',
#       '&',
#       'adventur',
#       'blockbust',
#       'action',
#       '&',
#       'adventur',
#       'critically-acclaim',
#       'action',
#       '&',
#       'adventur',
#       'critic',
#       'acclaim',
#       'film',
#       'oscar-win',
#       'film',
#       'modern',
#       'classic',
#       'golden',
#       'globe',
#       'award-win',
#       'film',
#       'action',
#       'movi',
#       'u',
#       'movi'],
#      'Title': 'Inglourious Basterds',
#      'Writer': ['Quentin Tarantino']},
#     '_type': '_doc'},
#    {'_id': 'Kt6v3noBRRNrcnq5kWXa',
#     '_index': 'netflix',
#     '_score': 7.3616014,
#     '_source': {'Actors': ['Tim Roth',
#       ' Amanda Plummer',
#       ' Laura Lovelace',
#       ' John Travolta'],
#      'Average Score': 0.8025,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['crime', 'drama'],
#      'Languages': ['English', ' Spanish', ' French'],
#      'Release Date': '1994',
#      'Series or Movie': 'Movie',
#      'Summary': ['quentin',
#       'tarantino',
#       'styliz',
#       'crime',
#       'caper',
#       'weav',
#       'togeth',
#       'stori',
#       'featur',
#       'burger-lov',
#       'hit',
#       'man',
#       'philosoph',
#       'partner',
#       'washed-up',
#       'boxer',
#       '.'],
#      'Tags': ['independ',
#       'drama',
#       'drama',
#       'independ',
#       'film',
#       'thriller',
#       'gangster',
#       'film',
#       'film',
#       'noir',
#       'polic',
#       'thriller',
#       'polic',
#       'drama',
#       'polic',
#       'movi',
#       'crime',
#       'thriller',
#       'crime',
#       'drama',
#       'independ',
#       'thriller',
#       'classic',
#       'drama',
#       'classic',
#       'movi',
#       'crime',
#       'movi'],
#      'Title': 'Pulp Fiction',
#      'Writer': ['Quentin Tarantino', ' Roger Avary']},
#     '_type': '_doc'},
#    {'_id': 'Vt6v3noBRRNrcnq5k2VO',
#     '_index': 'netflix',
#     '_score': 7.3616014,
#     '_source': {'Actors': ['Tim Roth',
#       ' Michael Madsen',
#       ' Harvey Keitel',
#       ' Chris Penn'],
#      'Average Score': 0.74,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['crime', 'drama', 'thriller'],
#      'Languages': ['English'],
#      'Release Date': '1992',
#      'Series or Movie': 'Movie',
#      'Summary': ['quentin',
#       'tarantino',
#       'raw',
#       'directori',
#       'debut',
#       'botch',
#       'robberi',
#       'indic',
#       'polic',
#       'inform',
#       'pressur',
#       'mount',
#       'aftermath',
#       'warehous',
#       '.'],
#      'Tags': ['independ',
#       'film',
#       'thriller',
#       'gangster',
#       'film',
#       'film',
#       'noir',
#       'polic',
#       'thriller',
#       'polic',
#       'movi',
#       'crime',
#       'thriller',
#       'independ',
#       'thriller',
#       'crime',
#       'film',
#       'cult',
#       'film',
#       'heist',
#       'film',
#       'classic',
#       'film',
#       'classic',
#       'thriller'],
#      'Title': 'Reservoir Dogs',
#      'Writer': ['Quentin Tarantino', ' Roger Avary']},
#     '_type': '_doc'},
#    {'_id': '0d6u3noBRRNrcnq5CjjZ',
#     '_index': 'netflix',
#     '_score': 4.089296,
#     '_source': {'Actors': ['Jessica Alba',
#       ' Devon Aoki',
#       ' Powers Boothe',
#       ' Alexis Bledel'],
#      'Average Score': 0.675,
#      'Director': ['Robert Rodriguez', ' Quentin Tarantino', ' Frank Miller'],
#      'Genre': ['crime', 'thriller'],
#      'Languages': ['English'],
#      'Release Date': '2005',
#      'Series or Movie': 'Movie',
#      'Summary': ['busi',
#       'coupl',
#       'tri',
#       'give',
#       'love',
#       'life',
#       'boost',
#       'take',
#       'impromptu',
#       'weekend',
#       'trip',
#       'onli',
#       'find',
#       'relationship',
#       'test',
#       'unexpect',
#       'way',
#       '.'],
#      'Tags': ['african',
#       'movi',
#       'psycholog',
#       'thriller',
#       'thriller',
#       'movi',
#       'mysteri',
#       'intern',
#       'thriller',
#       'steami',
#       'thriller',
#       'steami',
#       'thriller'],
#      'Title': 'Sin City',
#      'Writer': ['Robert Rodriguez', ' Frank Miller']},
#     '_type': '_doc'}],
#   'max_score': 7.3616014,
#   'total': {'relation': 'eq', 'value': 9}},
#  'timed_out': False,
#  'took': 10}

# %%
query_body = {
    'query' :{
        'match' :{
            'Title' : 'Lets Fight Ghost'
        }
    }
}

explain=True

results = es.search(index=index_name, body=query_body, explain=explain)['hits']['hits']
for hit in results:
  print('Title: {} - Director: {} - score: {}'.format(hit['_source']['Title'], hit['_source']['Director'], hit['_score']))
# Out:
# Title: Lets Fight Ghost - Director: ['Tomas Alfredson'] - score: 20.152025
# Title: Lets Dance - Director: ['Tomas Alfredson'] - score: 8.814203
# Title: Lets Dance - Director: ['Ladislas Chollat'] - score: 8.814203
# Title: Fist Fight - Director: ['Richie Keen'] - score: 7.9699717
# Title: Ghost - Director: ['Jerry Zucker'] - score: 7.805466
# Title: Lets Eat 2 - Director: ['nan'] - score: 7.6067967
# Title: Lets Be Cops - Director: ['Luke Greenfield'] - score: 7.6067967
# Title: Ultra Fight Victory - Director: ['nan'] - score: 6.8782115
# Title: S.W.A.T.: Fire Fight - Director: ['Benny Boom'] - score: 6.8782115
# Title: Ghost Buddies - Director: ['Simon Sek'] - score: 6.5665264
