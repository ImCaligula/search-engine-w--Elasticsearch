# %% [markdown]
# ## Loading Elasticsearch
#
# In this section Elasticsearch is installed on the colab machine and initialised. The scripts to be able to run it on Colab were provided by GitHub user [korakot](https://gist.github.com/korakot/15fe4f18d0e0f53d7b834ef797880500).

# %%
# !wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-7.0.0-linux-x86_64.tar.gz -q # it's an older version of Elasticsearch, latest release being 7.13.4, couldn't make it run with that
# !tar -xzf elasticsearch-7.0.0-linux-x86_64.tar.gz
# !chown -R daemon:daemon elasticsearch-7.0.0
# !pip install elasticsearch -q

# %%
import os
from subprocess import Popen, PIPE, STDOUT

# %% [markdown]
# This cell runs Elasticsearch in the hosted runtime machine.

# %%
es_server = Popen(['elasticsearch-7.0.0/bin/elasticsearch'], 
                  stdout=PIPE, stderr=STDOUT,
                  preexec_fn=lambda: os.setuid(1)  # as daemon
                 )

# %% [markdown]
# The next command is using [cURL](https://curl.se/), which is used as a REST API to communicate with the Elasticsearch client. In this case it is adapting te request in query DSL (Elasticsearch's proprietary language). It's just checking if Elasticsearch is running locally (in the google machine in this case) by querying its default port (`localhost:9200`)

# %%
# !curl -X GET "localhost:9200/"
# Out:
# {
#   "name" : "4669f306e673",
#   "cluster_name" : "elasticsearch",
#   "cluster_uuid" : "c4lEJg5jQYSaPpa-Tn9SGw",
#   "version" : {
#     "number" : "7.0.0",
#     "build_flavor" : "default",
#     "build_type" : "tar",
#     "build_hash" : "b7e28a7",
#     "build_date" : "2019-04-05T22:55:32.697037Z",
#     "build_snapshot" : false,
#     "lucene_version" : "8.0.0",
#     "minimum_wire_compatibility_version" : "6.7.0",
#     "minimum_index_compatibility_version" : "6.0.0-beta1"
#   },
#   "tagline" : "You Know, for Search"
# }

# %%
from elasticsearch import Elasticsearch

# %%
es = Elasticsearch()
es.ping() # another way to test whether ES is running, returns True if so
# Out:
# True

# %% [markdown]
# Elasticsearch should be running fine. Before creating an index, it is worth it to preprocess the data.
#
# ## Preprocessing

# %%
import pandas as pd
import numpy as np
import nltk
import re
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Next cell loads the dataset. It is available on [Kaggle](https://www.kaggle.com/ashishgup/netflix-rotten-tomatoes-metacritic-imdb), it is currently being updated to the local runtime directly as using code to download it directly requires a personal Kaggle API  token.

# %%
films = pd.read_csv("netflix-rotten-tomatoes-metacritic-imdb.csv")
films.head()
# Out:
#                  Title  ... Trailer Site
# 0     Lets Fight Ghost  ...          NaN
# 1  HOW TO BUILD A GIRL  ...      YouTube
# 2           Centigrade  ...      YouTube
# 3                ANNE+  ...          NaN
# 4                Moxie  ...          NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# The next cell contains the preprocessing functions.

# %%
def query_processor(query):
    query = re.sub(r"(\w)([.,;:!?'\"”\)])", r"\1 \2", query)
    query = re.sub(r"([.,;:!?'\"“\(])(\w)", r"\1 \2", query)
    query = re.sub("'", "", query)
    query = re.sub(",", "", query)
    tokens = re.split(r"\s+",query)
    tokens = [t.lower() for t in tokens]
    # Stemming with the SnowballStemmer for more efficiency
    s_stemmer = SnowballStemmer("english")
    stemedList = []
    for word in tokens:
        stemedList.append(s_stemmer.stem(word))
    tokens = stemedList
    # Lemmatising the tokens
    wordnet_lemmatiser = WordNetLemmatizer()
    lemmaList = []
    for word in stemedList:
        lemmaList.append(wordnet_lemmatiser.lemmatize(word))
    tokens = lemmaList
    # Finally remove stopwords
    stops = set(stopwords.words("english"))
    tokens = [word for word in tokens if not word in stops]
    return tokens

def dataset_processor(dataset):
    dataset = pd.read_csv("netflix-rotten-tomatoes-metacritic-imdb.csv")
    dataset = dataset.drop(columns = ["Trailer Site", "TMDb Trailer", "Poster", "Image", "IMDb Votes", "Netflix Link", "Production House", "Netflix Release Date", "Boxoffice", "Awards Received", "Awards Nominated For", "IMDb Link", "Runtime", "Country Availability", "View Rating"])
    dataset["Average Score"] = dataset.apply(Average, axis = 1)
    dataset = dataset.drop(columns = ["Hidden Gem Score", "IMDb Score", "Rotten Tomatoes Score", "Metacritic Score"])
    dataset = dataset.astype({"Title":"str", "Genre":"str", "Tags":"str",
                     "Languages":"str", "Series or Movie":"category",
                     "Director":"str", "Writer":"str", "Actors":"str",
                     "Summary":"str", "Average Score":"float"})
    # So need to query processor the summary, genre list and tag list.
    for i in ["Summary", "Genre", "Tags"]:
      dataset[i] = dataset.loc[:, i].apply(query_processor)

    # Need to turn the director, writer, languages, and actors into a list.
    for i in ["Director", "Languages", "Writer", "Actors"]:
      dataset[i] = dataset.loc[:,i].apply(Split)

    # Change the release data to just the year
    dataset["Release Date"] = dataset["Release Date"].apply(Year)
    return dataset

def Split(row):
  tokens = re.split(",", row)
  return tokens

def Year(row):
  tokens = re.split(" ", str(row))
  if tokens[0] == "nan":
    return "NaN"
  else:
    return tokens[2]

def Average(row):
  scores = []
  scorers = ["Hidden Gem Score", "IMDb Score", "Rotten Tomatoes Score", "Metacritic Score"]
  potential = [10,10,100,100]
  for i in range(len(scorers)):
    if (np.isnan(row.loc[scorers[i]])) == False:
      scores.append(row.loc[scorers[i]]/potential[i])
  if len(scores) > 0:
    return sum(scores)/len(scores)
  else:
    return "NaN"

# %%
# preprocessing the dataset
films = dataset_processor(films)
films.head()
# Out:
#                  Title  ... Average Score
# 0     Lets Fight Ghost  ...         0.755
# 1  HOW TO BUILD A GIRL  ...         0.690
# 2           Centigrade  ...         0.510
# 3                ANNE+  ...         0.710
# 4                Moxie  ...         0.720
#
# [5 rows x 11 columns]

# %%
films[films['Average Score'].isna()]
# Out:
#                                  Title  ... Average Score
# 208                      The Strongest  ...           NaN
# 220                       Firefly Lane  ...           NaN
# 246                         Le Tournoi  ...           NaN
# 248                        She is King  ...           NaN
# 249        How to Eliminate My Teacher  ...           NaN
# ...                                ...  ...           ...
# 15471         DreamWorks Short Stories  ...           NaN
# 15472         DreamWorks Shrek Stories  ...           NaN
# 15474            Nijntje and Vriendjes  ...           NaN
# 15475           K-POP Extreme Survival  ...           NaN
# 15476  DreamWorks Shreks Swamp Stories  ...           NaN
#
# [2086 rows x 11 columns]

# %%
films.dropna(subset=['Average Score'], inplace=True)

films[films['Average Score'].isna()]
# Out:
# Empty DataFrame
# Columns: [Title, Genre, Tags, Languages, Series or Movie, Director, Writer, Actors, Release Date, Summary, Average Score]
# Index: []

# %% [markdown]
# ## Indexing the documents

# %%
film_list = films.values.tolist()

# %%
films.dtypes
# Out:
# Title                object
# Genre                object
# Tags                 object
# Languages            object
# Series or Movie    category
# Director             object
# Writer               object
# Actors               object
# Release Date         object
# Summary              object
# Average Score       float64
# dtype: object

# %% [markdown]
# Creating the index in Elasticsearch ([API](https://www.elastic.co/guide/en/elasticsearch/reference/current/indices-create-index.html)).

# %%
index_body = {
    'settings': {
        'number_of_shards': 1,
        'number_of_replicas': 1,
        
    },
    'mappings': {
          'properties': {
              'Title': {'type': 'text'},
              'Genre': {'type': 'keyword'},
              'Tags' : {'type': 'keyword'},
              'Languages': {'type': 'keyword'},
              'Series or Movie' : {'type' : 'keyword'},
              'Director' : {'type': 'text'},
              'Writer' : {'type': 'text'},
              'Actors' : {'type': 'text'},
              'Release Date' : {'type': 'integer'},
              'Summary' : {'type': 'text'},
              'Average Score' : {'type': 'double'}  
          }
    }
}

# %%
index_name = 'netflix'

es.indices.delete(index='netflix', ignore=[400, 404]) # useful during development to reset the index
es.indices.create(index_name, body=index_body)
# Out:
# {'acknowledged': True, 'index': 'netflix', 'shards_acknowledged': True}

# %%
for title, genre, tags, languages, series_or_movie, director, writer, actors, release_date, summary, avg_score in film_list:
  list_body = {
      'Title': title,
      'Genre': genre,
      'Tags' : tags,
      'Languages': languages,
      'Series or Movie' : series_or_movie,
      'Director' : director,
      'Writer' : writer,
      'Actors' : actors,
      'Release Date' : release_date,
      'Summary' : summary,
      'Average Score' : avg_score
  }
  es.index(index_name, list_body)

# %%
es.cat.count(index='netflix',h=['count'])
# Out:
# '13394\n'

# %%
es.search(index="netflix", body={"query": {"match_all": {}}})
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': 'Behu33oBXeShiYZJz4_9',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Takumi Kitamura',
#       ' Masahiro Higashide',
#       ' Mackenyu',
#       ' Aoi Morikawa'],
#      'Average Score': 0.685,
#      'Director': ['Eiichirô Hasumi'],
#      'Genre': ['action'],
#      'Languages': ['Japanese'],
#      'Release Date': '2018',
#      'Series or Movie': 'Movie',
#      'Summary': ['risk-tak',
#       'driver',
#       'rivalri',
#       'steadi',
#       'mechan',
#       'brother',
#       'threaten',
#       'team',
#       'ultim',
#       'goal',
#       'win',
#       'place',
#       'world',
#       'ralli',
#       'championship',
#       '.'],
#      'Tags': ['action', '&', 'adventur', 'japanes', 'movi'],
#      'Title': 'Over Drive',
#      'Writer': ['nan']},
#     '_type': '_doc'},
#    {'_id': 'Buhu33oBXeShiYZJ0I8R',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Sophia Lillis',
#       ' Finn Wolfhard',
#       ' Jaeden Martell',
#       ' Jeremy Ray Taylor'],
#      'Average Score': 0.6649999999999999,
#      'Director': ['Andy Muschietti'],
#      'Genre': ['horror'],
#      'Languages': ['English', ' Hebrew'],
#      'Release Date': '2017',
#      'Series or Movie': 'Movie',
#      'Summary': ['hitoshi',
#       'spiral',
#       'bizarr',
#       'ident',
#       'crisi',
#       'simpl',
#       'prank',
#       'caus',
#       'multipl',
#       'version',
#       'start',
#       'show',
#       'town',
#       '!'],
#      'Tags': ['dark',
#       'comedi',
#       'comedi',
#       'thriller',
#       'movi',
#       'movi',
#       'base',
#       'book',
#       'japanes',
#       'movi'],
#      'Title': 'Its Me, Its Me',
#      'Writer': ['Gary Dauberman',
#       ' Chase Palmer',
#       ' Stephen King',
#       ' Cary Joji Fukunaga']},
#     '_type': '_doc'},
#    {'_id': 'B-hu33oBXeShiYZJ0I8d',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Ashenafi Nigusu',
#       ' Joseph Reta Belay',
#       ' Mikias Wolde',
#       ' Samrawit Desalegn'],
#      'Average Score': 0.8999999999999999,
#      'Director': ['Jan Philipp Weyl'],
#      'Genre': ['drama'],
#      'Languages': ['Amharic'],
#      'Release Date': '2019',
#      'Series or Movie': 'Movie',
#      'Summary': ['two',
#       'brother',
#       'rural',
#       'ethiopia',
#       'part',
#       'way',
#       'kid',
#       'pursu',
#       'respect',
#       'passion',
#       'run',
#       'photographi',
#       'onli',
#       'cross',
#       'path',
#       'adult',
#       '.'],
#      'Tags': ['african',
#       'film',
#       'social',
#       'issu',
#       'drama',
#       'sport',
#       'film',
#       'drama',
#       'sport',
#       'drama'],
#      'Title': 'Running Against the Wind',
#      'Writer': ['Jan Philipp Weyl', ' Michael Wogh']},
#     '_type': '_doc'},
#    {'_id': 'COhu33oBXeShiYZJ0I8p',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Iván Arana',
#       ' Juan Ríos',
#       ' Fernanda Castillo',
#       ' Valery Sais'],
#      'Average Score': 0.56,
#      'Director': ['Agustín Tapia'],
#      'Genre': ['horror', 'thriller'],
#      'Languages': ['Spanish'],
#      'Release Date': '2020',
#      'Series or Movie': 'Movie',
#      'Summary': ['dure',
#       'birthday',
#       'getaway',
#       'young',
#       'girl',
#       'receiv',
#       'jester',
#       'puppet',
#       'magic',
#       'reveal',
#       'chill',
#       'secret',
#       'behavior',
#       'parent',
#       'uncl',
#       '.'],
#      'Tags': ['mexican',
#       'movi',
#       'horror',
#       'movi',
#       'thriller',
#       'movi',
#       'supernatur',
#       'thriller',
#       'supernatur',
#       'horror',
#       'movi'],
#      'Title': 'Cuidado con lo que deseas',
#      'Writer': ['Agustín Tapia']},
#     '_type': '_doc'},
#    {'_id': 'Cehu33oBXeShiYZJ0I80',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Valérie Mairesse',
#       ' Sacha Briquet',
#       ' Gérard Lecaillon',
#       ' Anaïs Jeanneret'],
#      'Average Score': 0.595,
#      'Director': ['Christian Le Hémonet'],
#      'Genre': ['comedi', 'drama'],
#      'Languages': ['French'],
#      'Release Date': '1987',
#      'Series or Movie': 'Movie',
#      'Summary': ['student',
#       'must',
#       'navig',
#       'issu',
#       'sexual',
#       'ident',
#       'famili',
#       'amid',
#       'sri',
#       'lanka',
#       'social',
#       'turmoil',
#       '1970s',
#       '1980s',
#       '.'],
#      'Tags': ['lgbtq',
#       'drama',
#       'social',
#       'issu',
#       'drama',
#       'drama',
#       'lgbtq',
#       'film',
#       'film',
#       'base',
#       'book',
#       'canadian',
#       'film'],
#      'Title': 'Funny Boy',
#      'Writer': ['Gérard Lecaillon', ' Christian Le Hémonet']},
#     '_type': '_doc'},
#    {'_id': 'Cuhu33oBXeShiYZJ0I8-',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Peter Cushing',
#       ' Bernard Cribbins',
#       ' John Richardson',
#       ' Ursula Andress'],
#      'Average Score': 0.4766666666666666,
#      'Director': ['Robert Day'],
#      'Genre': ['adventur', 'fantasi'],
#      'Languages': ['English'],
#      'Release Date': '1965',
#      'Series or Movie': 'Movie',
#      'Summary': ['best',
#       'friend',
#       'get',
#       'strand',
#       'rain',
#       'becom',
#       'subject',
#       'romant',
#       'viral',
#       'video',
#       'morn',
#       'show',
#       'host',
#       'must',
#       'confront',
#       'true',
#       'feel',
#       '.'],
#      'Tags': ['romant',
#       'drama',
#       'drama',
#       'romant',
#       'movi',
#       'filipino',
#       'movi'],
#      'Title': 'Shes the One',
#      'Writer': ['H. Rider Haggard', ' David T. Chantler']},
#     '_type': '_doc'},
#    {'_id': 'C-hu33oBXeShiYZJ0I9I',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Martin del Rosario',
#       ' Paolo Ballesteros',
#       ' John Arcilla',
#       ' Christian Bables'],
#      'Average Score': 0.655,
#      'Director': ['Jun Lana'],
#      'Genre': ['comedi'],
#      'Languages': ['Tagalog', ' Filipino'],
#      'Release Date': '2019',
#      'Series or Movie': 'Movie',
#      'Summary': ['three',
#       'gay',
#       'sibl',
#       'told',
#       'termin',
#       'ill',
#       'father',
#       'must',
#       'produc',
#       'grandchild',
#       'order',
#       'inherit',
#       'share',
#       'fortun',
#       '.'],
#      'Tags': ['lgbtq',
#       'movi',
#       'comedi',
#       'slapstick',
#       'comedi',
#       'filipino',
#       'movi'],
#      'Title': 'The Panti Sisters',
#      'Writer': ['nan']},
#     '_type': '_doc'},
#    {'_id': 'DOhu33oBXeShiYZJ0I9T',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Natasha Calis',
#       ' Farryn VanHumbeck',
#       ' Candace Cameron Bure',
#       ' Ty Olsson'],
#      'Average Score': 0.6466666666666666,
#      'Director': ['Kristoffer Tabori'],
#      'Genre': ['comedi', 'romanc'],
#      'Languages': ['English'],
#      'Release Date': '2015',
#      'Series or Movie': 'Movie',
#      'Summary': ['overconfid',
#       'teen',
#       'bet',
#       'make',
#       'home',
#       'transfer',
#       'student',
#       'fall',
#       'love',
#       '30',
#       'day',
#       '—',
#       'wager',
#       'start',
#       'play',
#       'game',
#       'heart',
#       '.'],
#      'Tags': ['teen',
#       'movi',
#       'romant',
#       'movi',
#       'movi',
#       'base',
#       'book',
#       'filipino',
#       'movi'],
#      'Title': 'Just The Way You Are',
#      'Writer': ['Michael J. Murray']},
#     '_type': '_doc'},
#    {'_id': 'Dehu33oBXeShiYZJ0I9f',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Matilda De Angelis',
#       ' Elio Germano',
#       ' Leonardo Lidi',
#       ' Tom Wlaschiha'],
#      'Average Score': 0.5249999999999999,
#      'Director': ['Sydney Sibilia'],
#      'Genre': ['adventur', 'comedi', 'drama'],
#      'Languages': ['Italian', ' French', ' German'],
#      'Release Date': '2020',
#      'Series or Movie': 'Movie',
#      'Summary': ['idealist',
#       'engin',
#       'build',
#       'island',
#       'coast',
#       'itali',
#       'declar',
#       'nation',
#       'draw',
#       'attent',
#       'world',
#       '—',
#       'govern',
#       '.'],
#      'Tags': ['movi',
#       'base',
#       'real',
#       'life',
#       'social',
#       'issu',
#       'drama',
#       'drama',
#       'comedi',
#       'italian',
#       'movi'],
#      'Title': 'Rose Island',
#      'Writer': ['Sydney Sibilia', ' Francesca Manieri']},
#     '_type': '_doc'},
#    {'_id': 'Duhu33oBXeShiYZJ0I9q',
#     '_index': 'netflix',
#     '_score': 1.0,
#     '_source': {'Actors': ['Eliska Krenková',
#       ' Zdenek Mucha',
#       ' Jan Frantisek Uher',
#       ' Tomás Mrvík'],
#      'Average Score': 0.7566666666666667,
#      'Director': ['Olmo Omerzu'],
#      'Genre': ['adventur', 'comedi', 'drama'],
#      'Languages': ['Czech'],
#      'Release Date': '2018',
#      'Series or Movie': 'Movie',
#      'Summary': ['two',
#       'teen',
#       'boy',
#       'run',
#       'away',
#       'home',
#       'pick',
#       'pretti',
#       'hitchhik',
#       'road',
#       'trip',
#       'lead',
#       'come',
#       'age',
#       'friendship',
#       'love',
#       'rebellion',
#       'collid',
#       '.'],
#      'Tags': ['czech', 'movi', 'teen', 'movi', 'drama'],
#      'Title': 'Winter Flies',
#      'Writer': ['Petr Pýcha']},
#     '_type': '_doc'}],
#   'max_score': 1.0,
#   'total': {'relation': 'gte', 'value': 10000}},
#  'timed_out': False,
#  'took': 3}

# %%
es.search(index="netflix", body={"query":{'term': {'Genre' : 'crime'}} })
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': 'GOhu33oBXeShiYZJ0I_n',
#     '_index': 'netflix',
#     '_score': 2.6023657,
#     '_source': {'Actors': ['Damien Bonnard',
#       ' Laure Calamy',
#       ' Denis Ménochet',
#       ' Nadia Tereszkiewicz'],
#      'Average Score': 0.71,
#      'Director': ['Dominik Moll'],
#      'Genre': ['crime', 'drama', 'mysteri', 'thriller'],
#      'Languages': ['French'],
#      'Release Date': '2019',
#      'Series or Movie': 'Movie',
#      'Summary': ['woman',
#       'mysteri',
#       'disappear',
#       'dure',
#       'snowstorm',
#       'franc',
#       'connect',
#       'live',
#       'unravel',
#       'secret',
#       'five',
#       'peopl',
#       'two',
#       'contin',
#       '.'],
#      'Tags': ['drama',
#       'crime',
#       'film',
#       'crime',
#       'drama',
#       'film',
#       'base',
#       'book',
#       'mysteri',
#       'french',
#       'film'],
#      'Title': 'Only the Animals',
#      'Writer': ['Gilles Marchand', ' Dominik Moll', ' Colin Niel']},
#     '_type': '_doc'},
#    {'_id': 'P-hu33oBXeShiYZJ0o-M',
#     '_index': 'netflix',
#     '_score': 2.6023657,
#     '_source': {'Actors': ['Alli Neumann',
#       ' Sascha Alexander Gersak',
#       ' Sophia Thomalla',
#       ' Kostja Ullmann'],
#      'Average Score': 0.585,
#      'Director': ['Detlev Buck'],
#      'Genre': ['comedi', 'crime', 'thriller'],
#      'Languages': ['German', ' English'],
#      'Release Date': '2020',
#      'Series or Movie': 'Movie',
#      'Summary': ['man',
#       'foil',
#       'attempt',
#       'murder',
#       'flee',
#       'crew',
#       'would-b',
#       'killer',
#       'along',
#       'intend',
#       'target',
#       'woman',
#       'met',
#       'tri',
#       'find',
#       '.'],
#      'Tags': ['dark',
#       'comedi',
#       'dark',
#       'comedi',
#       'dark',
#       'comedi',
#       'comedi',
#       'comedi',
#       'comedi',
#       'thriller',
#       'movi',
#       'thriller',
#       'movi',
#       'thriller',
#       'german',
#       'movi',
#       'german',
#       'movi',
#       'german',
#       'film'],
#      'Title': 'Christmas Crossfire',
#      'Writer': ['Martin Behnke', ' Detlev Buck']},
#     '_type': '_doc'},
#    {'_id': 'ROhu33oBXeShiYZJ0o_D',
#     '_index': 'netflix',
#     '_score': 2.6023657,
#     '_source': {'Actors': ['Rodica Lazar',
#       ' Vlad Ivanov',
#       ' Agustí Villaronga',
#       ' Catrinel Marlon'],
#      'Average Score': 0.6766666666666667,
#      'Director': ['Corneliu Porumboiu'],
#      'Genre': ['comedi', 'crime', 'drama', 'thriller'],
#      'Languages': ['Romanian', ' English', ' Spanish'],
#      'Release Date': '2019',
#      'Series or Movie': 'Movie',
#      'Summary': ['shadi',
#       'polic',
#       'inspector',
#       'team',
#       'beauti',
#       'accomplic',
#       'high-stak',
#       'heist',
#       '.',
#       'pull',
#       'theyll',
#       'communic',
#       'use',
#       'secret',
#       'whistl',
#       'languag',
#       '.'],
#      'Tags': ['dark',
#       'comedi',
#       'crime',
#       'comedi',
#       'crime',
#       'film',
#       'comedi',
#       'thriller',
#       'crime',
#       'thriller',
#       'heist',
#       'film',
#       'gangster',
#       'film',
#       'german',
#       'film'],
#      'Title': 'The Whistlers',
#      'Writer': ['Corneliu Porumboiu']},
#     '_type': '_doc'},
#    {'_id': 'Vehu33oBXeShiYZJ04-S',
#     '_index': 'netflix',
#     '_score': 2.6023657,
#     '_source': {'Actors': ['Steven Seagal',
#       ' William Sadler',
#       ' Frederick Coffin',
#       ' Kelly LeBrock'],
#      'Average Score': 0.39999999999999997,
#      'Director': ['Bruce Malmuth'],
#      'Genre': ['action', 'crime', 'drama', 'thriller'],
#      'Languages': ['English'],
#      'Release Date': '1990',
#      'Series or Movie': 'Movie',
#      'Summary': ['investig',
#       'corrupt',
#       'politician',
#       'mason',
#       'storm',
#       'gun',
#       'left',
#       'dead',
#       '.',
#       'nurs',
#       'help',
#       'recov',
#       'exact',
#       'reveng',
#       '.'],
#      'Tags': ['action',
#       '&',
#       'adventur',
#       'crime',
#       'action',
#       '&',
#       'adventur',
#       'action',
#       'thriller'],
#      'Title': 'Hard to Kill',
#      'Writer': ['Steven McKay']},
#     '_type': '_doc'},
#    {'_id': 'Wuhu33oBXeShiYZJ04_J',
#     '_index': 'netflix',
#     '_score': 2.6023657,
#     '_source': {'Actors': ['Alexandra Sakelaropoulou',
#       ' Minas Hatzisavvas',
#       ' Giorgos Ninios',
#       ' Yiorgos Moroyiannis'],
#      'Average Score': 0.715,
#      'Director': ['Nikos Grammatikos'],
#      'Genre': ['action', 'crime', 'drama'],
#      'Languages': ['Greek'],
#      'Release Date': '1991',
#      'Series or Movie': 'Movie',
#      'Summary': ['young',
#       'report',
#       'investig',
#       'string',
#       'grisli',
#       'suicid',
#       'take',
#       'danger',
#       'detour',
#       'follow',
#       'clue',
#       'cur',
#       'stretch',
#       'road',
#       '.'],
#      'Tags': ['horror',
#       'movi',
#       'filipino',
#       'movi',
#       'supernatur',
#       'horror',
#       'movi'],
#      'Title': 'U-Turn',
#      'Writer': ['Minas Hatzisavvas',
#       ' Nikos Grammatikos',
#       ' Fotini Siskopoulou']},
#     '_type': '_doc'},
#    {'_id': 'p-hu33oBXeShiYZJwI0N',
#     '_index': 'netflix',
#     '_score': 2.6023657,
#     '_source': {'Actors': ['Román Ariznavarreta',
#       ' Ismael Abellán',
#       ' Iván Aledo',
#       ' Pedro Basanta'],
#      'Average Score': 0.8200000000000001,
#      'Director': ['Gerardo Herrero'],
#      'Genre': ['crime'],
#      'Languages': ['Spanish'],
#      'Release Date': '1988',
#      'Series or Movie': 'Movie',
#      'Summary': ['look',
#       'fresh',
#       'start',
#       'park',
#       'ranger',
#       'get',
#       'new',
#       'assign',
#       '.',
#       'discov',
#       'network',
#       'poacher',
#       'surviv',
#       'depend',
#       'lethal',
#       'instinct',
#       '.'],
#      'Tags': ['argentinian', 'film', 'thriller'],
#      'Title': 'Al acecho',
#      'Writer': ['Juan Madrid', ' Gonzalo Herrero']},
#     '_type': '_doc'},
#    {'_id': 'qOhu33oBXeShiYZJwI0Z',
#     '_index': 'netflix',
#     '_score': 2.6023657,
#     '_source': {'Actors': ['Ivana Lotito',
#       ' Bianca Guaccero',
#       ' Sergio Rubini',
#       ' Rocco Papaleo'],
#      'Average Score': 0.685,
#      'Director': ['Sergio Rubini'],
#      'Genre': ['crime', 'drama'],
#      'Languages': ['nan'],
#      'Release Date': '2019',
#      'Series or Movie': 'Movie',
#      'Summary': ['commit',
#       'robberi',
#       'thief',
#       'hide',
#       'empti',
#       'rooftop',
#       'water',
#       'tank',
#       'occupi',
#       'local',
#       'eccentr',
#       'believ',
#       'nativ',
#       'american',
#       '.'],
#      'Tags': ['drama', 'crime', 'movi', 'crime', 'drama', 'italian', 'movi'],
#      'Title': 'Il Grande Spirito',
#      'Writer': ['Carla Cavalluzzi', ' Angelo Pasquini', ' Sergio Rubini']},
#     '_type': '_doc'},
#    {'_id': 'qehu33oBXeShiYZJwI0l',
#     '_index': 'netflix',
#     '_score': 2.6023657,
#     '_source': {'Actors': ['Lorenzo Richelmy',
#       ' Claudia Gerini',
#       ' Luca Barbareschi',
#       ' Valentina Bellè'],
#      'Average Score': 0.63,
#      'Director': ['Fabio Resinaro'],
#      'Genre': ['comedi', 'crime'],
#      'Languages': ['Italian'],
#      'Release Date': '2019',
#      'Series or Movie': 'Movie',
#      'Summary': ['flounder',
#       'writer',
#       'team',
#       'film',
#       'produc',
#       'adapt',
#       'crime',
#       'novel',
#       'go',
#       'extrem',
#       'ensur',
#       'movi',
#       'get',
#       'made',
#       '.'],
#      'Tags': ['crime',
#       'comedi',
#       'comedi',
#       'italian',
#       'movi',
#       'movi',
#       'base',
#       'book'],
#      'Title': 'Dolceroma',
#      'Writer': ['Fausto Brizzi', ' Pino Corrias']},
#     '_type': '_doc'},
#    {'_id': 'quhu33oBXeShiYZJwI0v',
#     '_index': 'netflix',
#     '_score': 2.6023657,
#     '_source': {'Actors': ['Joe Biden',
#       ' George W. Bush',
#       ' Bill Clinton',
#       ' George Bush'],
#      'Average Score': 0.69,
#      'Director': ['Stanley Nelson'],
#      'Genre': ['documentari', 'crime', 'histori'],
#      'Languages': ['English'],
#      'Release Date': '2021',
#      'Series or Movie': 'Movie',
#      'Summary': ['cheap',
#       'power',
#       'drug',
#       'emerg',
#       'dure',
#       'recess',
#       'ignit',
#       'moral',
#       'panic',
#       'fuel',
#       'racism',
#       '.',
#       'explor',
#       'complex',
#       'histori',
#       'crack',
#       '1980s',
#       '.'],
#      'Tags': ['social', '&', 'cultur', 'doc', 'documentari', 'film'],
#      'Title': 'Crack: Cocaine, Corruption & Conspiracy',
#      'Writer': ['nan']},
#     '_type': '_doc'},
#    {'_id': 'r-hu33oBXeShiYZJwI1j',
#     '_index': 'netflix',
#     '_score': 2.6023657,
#     '_source': {'Actors': ['Shia LaBeouf',
#       ' Cinthya Carmona',
#       ' Jose Conejo Martin',
#       ' Bobby Soto'],
#      'Average Score': 0.30666666666666664,
#      'Director': ['David Ayer'],
#      'Genre': ['action', 'crime', 'drama', 'thriller'],
#      'Languages': ['Spanish', ' English'],
#      'Release Date': '2020',
#      'Series or Movie': 'Movie',
#      'Summary': ['famili',
#       'man',
#       'gang',
#       '"',
#       'tax',
#       'collector',
#       '"',
#       'david',
#       'discov',
#       'former',
#       'enemi',
#       'ha',
#       'return',
#       'wage',
#       'turf',
#       'war',
#       'threaten',
#       'bos',
#       'partner',
#       'creeper',
#       '.'],
#      'Tags': ['drama',
#       'crime',
#       'drama',
#       'thriller',
#       'crime',
#       'thriller',
#       'gangster',
#       'film'],
#      'Title': 'The Tax Collector',
#      'Writer': ['David Ayer']},
#     '_type': '_doc'}],
#   'max_score': 2.6023657,
#   'total': {'relation': 'eq', 'value': 1915}},
#  'timed_out': False,
#  'took': 3}

# %%
es.search(index="netflix", body={"query":{'match': {'Director' : 'Tarantino'}} })
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': 'iOhu33oBXeShiYZJ1Y_j',
#     '_index': 'netflix',
#     '_score': 7.3616014,
#     '_source': {'Actors': ['Tim Roth',
#       ' Amanda Plummer',
#       ' Laura Lovelace',
#       ' John Travolta'],
#      'Average Score': 0.8025,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['crime', 'drama'],
#      'Languages': ['English', ' Spanish', ' French'],
#      'Release Date': '1994',
#      'Series or Movie': 'Movie',
#      'Summary': ['shelter',
#       'young',
#       'woman',
#       'becom',
#       'enamor',
#       'struggl',
#       'writer',
#       'goe',
#       'great',
#       'length',
#       'becom',
#       'involv',
#       'creativ',
#       'process',
#       '.'],
#      'Tags': ['psycholog',
#       'thriller',
#       'independ',
#       'film',
#       'thriller',
#       'indonesian',
#       'film'],
#      'Title': 'Fiction.',
#      'Writer': ['Quentin Tarantino', ' Roger Avary']},
#     '_type': '_doc'},
#    {'_id': 'sehv33oBXeShiYZJMJey',
#     '_index': 'netflix',
#     '_score': 7.3616014,
#     '_source': {'Actors': ['Margot Robbie',
#       ' Brad Pitt',
#       ' Leonardo DiCaprio',
#       ' Emile Hirsch'],
#      'Average Score': 0.7125,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['comedi', 'drama'],
#      'Languages': ['English', ' Italian', ' Spanish', ' German'],
#      'Release Date': '2019',
#      'Series or Movie': 'Movie',
#      'Summary': ['1969',
#       '.',
#       'tv',
#       'actor',
#       'stunt-doubl',
#       'friend',
#       'weigh',
#       'next',
#       'move',
#       'la',
#       'rock',
#       'chang',
#       'scene',
#       'hottest',
#       'coupl',
#       'arriv',
#       'next',
#       'door',
#       '.'],
#      'Tags': ['drama', 'u', 'movi', 'comedi'],
#      'Title': 'Once Upon a Time in Hollywood',
#      'Writer': ['Quentin Tarantino']},
#     '_type': '_doc'},
#    {'_id': 'EOhv33oBXeShiYZJhp9J',
#     '_index': 'netflix',
#     '_score': 7.3616014,
#     '_source': {'Actors': ['Walton Goggins',
#       ' Samuel L. Jackson',
#       ' Jennifer Jason Leigh',
#       ' Kurt Russell'],
#      'Average Score': 0.6425,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['crime', 'drama', 'mysteri', 'thriller', 'western'],
#      'Languages': ['English', ' Spanish', ' French'],
#      'Release Date': '2015',
#      'Series or Movie': 'Series',
#      'Summary': ['trap',
#       'stagecoach',
#       'stop',
#       'storm',
#       'rage',
#       'outsid',
#       'two',
#       'bounti',
#       'hunter',
#       'outlaw',
#       'face',
#       'galleri',
#       'rogu',
#       '.',
#       'featur',
#       'never-before-seen',
#       'footag',
#       '.'],
#      'Tags': ['western', 'thriller', 'crime', 'thriller'],
#      'Title': 'The Hateful Eight: Extended Version',
#      'Writer': ['Quentin Tarantino']},
#     '_type': '_doc'},
#    {'_id': 'hOhw33oBXeShiYZJXbF8',
#     '_index': 'netflix',
#     '_score': 7.3616014,
#     '_source': {'Actors': ['Walton Goggins',
#       ' Samuel L. Jackson',
#       ' Jennifer Jason Leigh',
#       ' Kurt Russell'],
#      'Average Score': 0.6425,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['crime', 'drama', 'mysteri', 'thriller', 'western'],
#      'Languages': ['English', ' Spanish', ' French'],
#      'Release Date': '2015',
#      'Series or Movie': 'Movie',
#      'Summary': ['year',
#       'civil',
#       'war',
#       'bounti',
#       'hunter',
#       'captiv',
#       'waylaid',
#       'wyom',
#       'blizzard',
#       'hole',
#       'way',
#       'station',
#       'six',
#       'dicey',
#       'stranger',
#       '.'],
#      'Tags': ['adventur',
#       'action',
#       '&',
#       'adventur',
#       'period',
#       'piec',
#       'western',
#       'crime',
#       'movi',
#       'thriller',
#       'movi',
#       'crime',
#       'thriller'],
#      'Title': 'The Hateful Eight',
#      'Writer': ['Quentin Tarantino']},
#     '_type': '_doc'},
#    {'_id': 'guhw33oBXeShiYZJ4bzA',
#     '_index': 'netflix',
#     '_score': 7.3616014,
#     '_source': {'Actors': ['Jamie Foxx',
#       ' Christoph Waltz',
#       ' Kerry Washington',
#       ' Leonardo DiCaprio'],
#      'Average Score': 0.7350000000000001,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['drama', 'western'],
#      'Languages': ['English', ' German', ' French', ' Italian'],
#      'Release Date': '2012',
#      'Series or Movie': 'Movie',
#      'Summary': ['accompani',
#       'german',
#       'bounti',
#       'hunter',
#       'freed',
#       'slave',
#       'name',
#       'django',
#       'travel',
#       'across',
#       'america',
#       'free',
#       'wife',
#       'sadist',
#       'plantat',
#       'owner',
#       '.'],
#      'Tags': ['drama',
#       'western',
#       'period',
#       'piec',
#       'action',
#       '&',
#       'adventur',
#       'crime',
#       'action',
#       '&',
#       'adventur',
#       'crime',
#       'drama',
#       'social',
#       'issu',
#       'drama',
#       'crime',
#       'film',
#       'u',
#       'movi',
#       'award-win',
#       'drama'],
#      'Title': 'Django Unchained',
#      'Writer': ['Quentin Tarantino']},
#     '_type': '_doc'},
#    {'_id': 'zehw33oBXeShiYZJ8b2g',
#     '_index': 'netflix',
#     '_score': 7.3616014,
#     '_source': {'Actors': ['Mélanie Laurent',
#       ' Brad Pitt',
#       ' Christoph Waltz',
#       ' Eli Roth'],
#      'Average Score': 0.7025,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['adventur', 'drama', 'war'],
#      'Languages': ['English', ' German', ' French', ' Italian'],
#      'Release Date': '2009',
#      'Series or Movie': 'Movie',
#      'Summary': ['jewish',
#       'cinema',
#       'owner',
#       'occupi',
#       'pari',
#       'forc',
#       'host',
#       'nazi',
#       'premier',
#       'group',
#       'american',
#       'soldier',
#       'call',
#       'basterd',
#       'plan',
#       'face-off',
#       '.'],
#      'Tags': ['action',
#       'thriller',
#       'militari',
#       'action',
#       '&',
#       'adventur',
#       'spi',
#       'action',
#       '&',
#       'adventur',
#       'action',
#       '&',
#       'adventur',
#       'blockbust',
#       'action',
#       '&',
#       'adventur',
#       'critically-acclaim',
#       'action',
#       '&',
#       'adventur',
#       'critic',
#       'acclaim',
#       'film',
#       'oscar-win',
#       'film',
#       'modern',
#       'classic',
#       'golden',
#       'globe',
#       'award-win',
#       'film',
#       'action',
#       'movi',
#       'u',
#       'movi'],
#      'Title': 'Inglourious Basterds',
#      'Writer': ['Quentin Tarantino']},
#     '_type': '_doc'},
#    {'_id': 'Iuhx33oBXeShiYZJAb_P',
#     '_index': 'netflix',
#     '_score': 7.3616014,
#     '_source': {'Actors': ['Tim Roth',
#       ' Amanda Plummer',
#       ' Laura Lovelace',
#       ' John Travolta'],
#      'Average Score': 0.8025,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['crime', 'drama'],
#      'Languages': ['English', ' Spanish', ' French'],
#      'Release Date': '1994',
#      'Series or Movie': 'Movie',
#      'Summary': ['quentin',
#       'tarantino',
#       'styliz',
#       'crime',
#       'caper',
#       'weav',
#       'togeth',
#       'stori',
#       'featur',
#       'burger-lov',
#       'hit',
#       'man',
#       'philosoph',
#       'partner',
#       'washed-up',
#       'boxer',
#       '.'],
#      'Tags': ['independ',
#       'drama',
#       'drama',
#       'independ',
#       'film',
#       'thriller',
#       'gangster',
#       'film',
#       'film',
#       'noir',
#       'polic',
#       'thriller',
#       'polic',
#       'drama',
#       'polic',
#       'movi',
#       'crime',
#       'thriller',
#       'crime',
#       'drama',
#       'independ',
#       'thriller',
#       'classic',
#       'drama',
#       'classic',
#       'movi',
#       'crime',
#       'movi'],
#      'Title': 'Pulp Fiction',
#      'Writer': ['Quentin Tarantino', ' Roger Avary']},
#     '_type': '_doc'},
#    {'_id': 'Tuhx33oBXeShiYZJA7_l',
#     '_index': 'netflix',
#     '_score': 7.3616014,
#     '_source': {'Actors': ['Tim Roth',
#       ' Michael Madsen',
#       ' Harvey Keitel',
#       ' Chris Penn'],
#      'Average Score': 0.74,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['crime', 'drama', 'thriller'],
#      'Languages': ['English'],
#      'Release Date': '1992',
#      'Series or Movie': 'Movie',
#      'Summary': ['quentin',
#       'tarantino',
#       'raw',
#       'directori',
#       'debut',
#       'botch',
#       'robberi',
#       'indic',
#       'polic',
#       'inform',
#       'pressur',
#       'mount',
#       'aftermath',
#       'warehous',
#       '.'],
#      'Tags': ['independ',
#       'film',
#       'thriller',
#       'gangster',
#       'film',
#       'film',
#       'noir',
#       'polic',
#       'thriller',
#       'polic',
#       'movi',
#       'crime',
#       'thriller',
#       'independ',
#       'thriller',
#       'crime',
#       'film',
#       'cult',
#       'film',
#       'heist',
#       'film',
#       'classic',
#       'film',
#       'classic',
#       'thriller'],
#      'Title': 'Reservoir Dogs',
#      'Writer': ['Quentin Tarantino', ' Roger Avary']},
#     '_type': '_doc'},
#    {'_id': 'yehu33oBXeShiYZJ-JKl',
#     '_index': 'netflix',
#     '_score': 4.089296,
#     '_source': {'Actors': ['Jessica Alba',
#       ' Devon Aoki',
#       ' Powers Boothe',
#       ' Alexis Bledel'],
#      'Average Score': 0.675,
#      'Director': ['Robert Rodriguez', ' Quentin Tarantino', ' Frank Miller'],
#      'Genre': ['crime', 'thriller'],
#      'Languages': ['English'],
#      'Release Date': '2005',
#      'Series or Movie': 'Movie',
#      'Summary': ['busi',
#       'coupl',
#       'tri',
#       'give',
#       'love',
#       'life',
#       'boost',
#       'take',
#       'impromptu',
#       'weekend',
#       'trip',
#       'onli',
#       'find',
#       'relationship',
#       'test',
#       'unexpect',
#       'way',
#       '.'],
#      'Tags': ['african',
#       'movi',
#       'psycholog',
#       'thriller',
#       'thriller',
#       'movi',
#       'mysteri',
#       'intern',
#       'thriller',
#       'steami',
#       'thriller',
#       'steami',
#       'thriller'],
#      'Title': 'Sin City',
#      'Writer': ['Robert Rodriguez', ' Frank Miller']},
#     '_type': '_doc'}],
#   'max_score': 7.3616014,
#   'total': {'relation': 'eq', 'value': 9}},
#  'timed_out': False,
#  'took': 4}

# %%
query_body = {
    'query' :{
        'match' :{
            'Title' : 'Lets Fight Ghost'
        }
    }
}

explain=True

results = es.search(index=index_name, body=query_body, explain=explain)['hits']['hits']
for hit in results:
  print('Title: {} - Director: {} - score: {}'.format(hit['_source']['Title'], hit['_source']['Director'], hit['_score']))
# Out:
# Title: Lets Fight Ghost - Director: ['Tomas Alfredson'] - score: 20.152025
# Title: Lets Dance - Director: ['Tomas Alfredson'] - score: 8.814203
# Title: Lets Dance - Director: ['Ladislas Chollat'] - score: 8.814203
# Title: Fist Fight - Director: ['Richie Keen'] - score: 7.9699717
# Title: Ghost - Director: ['Jerry Zucker'] - score: 7.805466
# Title: Lets Eat 2 - Director: ['nan'] - score: 7.6067967
# Title: Lets Be Cops - Director: ['Luke Greenfield'] - score: 7.6067967
# Title: Ultra Fight Victory - Director: ['nan'] - score: 6.8782115
# Title: S.W.A.T.: Fire Fight - Director: ['Benny Boom'] - score: 6.8782115
# Title: Ghost Buddies - Director: ['Simon Sek'] - score: 6.5665264

# %% [markdown]
# **Compound query Search:**

# %%
es.search(index="netflix", body={"query":{'bool':{'must':[{'match': {'Director' : 'Tarantino'}}, {'match': {'Genre': 'crime'}}] }}})
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': 'iOhu33oBXeShiYZJ1Y_j',
#     '_index': 'netflix',
#     '_score': 9.963967,
#     '_source': {'Actors': ['Tim Roth',
#       ' Amanda Plummer',
#       ' Laura Lovelace',
#       ' John Travolta'],
#      'Average Score': 0.8025,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['crime', 'drama'],
#      'Languages': ['English', ' Spanish', ' French'],
#      'Release Date': '1994',
#      'Series or Movie': 'Movie',
#      'Summary': ['shelter',
#       'young',
#       'woman',
#       'becom',
#       'enamor',
#       'struggl',
#       'writer',
#       'goe',
#       'great',
#       'length',
#       'becom',
#       'involv',
#       'creativ',
#       'process',
#       '.'],
#      'Tags': ['psycholog',
#       'thriller',
#       'independ',
#       'film',
#       'thriller',
#       'indonesian',
#       'film'],
#      'Title': 'Fiction.',
#      'Writer': ['Quentin Tarantino', ' Roger Avary']},
#     '_type': '_doc'},
#    {'_id': 'EOhv33oBXeShiYZJhp9J',
#     '_index': 'netflix',
#     '_score': 9.963967,
#     '_source': {'Actors': ['Walton Goggins',
#       ' Samuel L. Jackson',
#       ' Jennifer Jason Leigh',
#       ' Kurt Russell'],
#      'Average Score': 0.6425,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['crime', 'drama', 'mysteri', 'thriller', 'western'],
#      'Languages': ['English', ' Spanish', ' French'],
#      'Release Date': '2015',
#      'Series or Movie': 'Series',
#      'Summary': ['trap',
#       'stagecoach',
#       'stop',
#       'storm',
#       'rage',
#       'outsid',
#       'two',
#       'bounti',
#       'hunter',
#       'outlaw',
#       'face',
#       'galleri',
#       'rogu',
#       '.',
#       'featur',
#       'never-before-seen',
#       'footag',
#       '.'],
#      'Tags': ['western', 'thriller', 'crime', 'thriller'],
#      'Title': 'The Hateful Eight: Extended Version',
#      'Writer': ['Quentin Tarantino']},
#     '_type': '_doc'},
#    {'_id': 'hOhw33oBXeShiYZJXbF8',
#     '_index': 'netflix',
#     '_score': 9.963967,
#     '_source': {'Actors': ['Walton Goggins',
#       ' Samuel L. Jackson',
#       ' Jennifer Jason Leigh',
#       ' Kurt Russell'],
#      'Average Score': 0.6425,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['crime', 'drama', 'mysteri', 'thriller', 'western'],
#      'Languages': ['English', ' Spanish', ' French'],
#      'Release Date': '2015',
#      'Series or Movie': 'Movie',
#      'Summary': ['year',
#       'civil',
#       'war',
#       'bounti',
#       'hunter',
#       'captiv',
#       'waylaid',
#       'wyom',
#       'blizzard',
#       'hole',
#       'way',
#       'station',
#       'six',
#       'dicey',
#       'stranger',
#       '.'],
#      'Tags': ['adventur',
#       'action',
#       '&',
#       'adventur',
#       'period',
#       'piec',
#       'western',
#       'crime',
#       'movi',
#       'thriller',
#       'movi',
#       'crime',
#       'thriller'],
#      'Title': 'The Hateful Eight',
#      'Writer': ['Quentin Tarantino']},
#     '_type': '_doc'},
#    {'_id': 'Iuhx33oBXeShiYZJAb_P',
#     '_index': 'netflix',
#     '_score': 9.963967,
#     '_source': {'Actors': ['Tim Roth',
#       ' Amanda Plummer',
#       ' Laura Lovelace',
#       ' John Travolta'],
#      'Average Score': 0.8025,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['crime', 'drama'],
#      'Languages': ['English', ' Spanish', ' French'],
#      'Release Date': '1994',
#      'Series or Movie': 'Movie',
#      'Summary': ['quentin',
#       'tarantino',
#       'styliz',
#       'crime',
#       'caper',
#       'weav',
#       'togeth',
#       'stori',
#       'featur',
#       'burger-lov',
#       'hit',
#       'man',
#       'philosoph',
#       'partner',
#       'washed-up',
#       'boxer',
#       '.'],
#      'Tags': ['independ',
#       'drama',
#       'drama',
#       'independ',
#       'film',
#       'thriller',
#       'gangster',
#       'film',
#       'film',
#       'noir',
#       'polic',
#       'thriller',
#       'polic',
#       'drama',
#       'polic',
#       'movi',
#       'crime',
#       'thriller',
#       'crime',
#       'drama',
#       'independ',
#       'thriller',
#       'classic',
#       'drama',
#       'classic',
#       'movi',
#       'crime',
#       'movi'],
#      'Title': 'Pulp Fiction',
#      'Writer': ['Quentin Tarantino', ' Roger Avary']},
#     '_type': '_doc'},
#    {'_id': 'Tuhx33oBXeShiYZJA7_l',
#     '_index': 'netflix',
#     '_score': 9.963967,
#     '_source': {'Actors': ['Tim Roth',
#       ' Michael Madsen',
#       ' Harvey Keitel',
#       ' Chris Penn'],
#      'Average Score': 0.74,
#      'Director': ['Quentin Tarantino'],
#      'Genre': ['crime', 'drama', 'thriller'],
#      'Languages': ['English'],
#      'Release Date': '1992',
#      'Series or Movie': 'Movie',
#      'Summary': ['quentin',
#       'tarantino',
#       'raw',
#       'directori',
#       'debut',
#       'botch',
#       'robberi',
#       'indic',
#       'polic',
#       'inform',
#       'pressur',
#       'mount',
#       'aftermath',
#       'warehous',
#       '.'],
#      'Tags': ['independ',
#       'film',
#       'thriller',
#       'gangster',
#       'film',
#       'film',
#       'noir',
#       'polic',
#       'thriller',
#       'polic',
#       'movi',
#       'crime',
#       'thriller',
#       'independ',
#       'thriller',
#       'crime',
#       'film',
#       'cult',
#       'film',
#       'heist',
#       'film',
#       'classic',
#       'film',
#       'classic',
#       'thriller'],
#      'Title': 'Reservoir Dogs',
#      'Writer': ['Quentin Tarantino', ' Roger Avary']},
#     '_type': '_doc'},
#    {'_id': 'yehu33oBXeShiYZJ-JKl',
#     '_index': 'netflix',
#     '_score': 6.691662,
#     '_source': {'Actors': ['Jessica Alba',
#       ' Devon Aoki',
#       ' Powers Boothe',
#       ' Alexis Bledel'],
#      'Average Score': 0.675,
#      'Director': ['Robert Rodriguez', ' Quentin Tarantino', ' Frank Miller'],
#      'Genre': ['crime', 'thriller'],
#      'Languages': ['English'],
#      'Release Date': '2005',
#      'Series or Movie': 'Movie',
#      'Summary': ['busi',
#       'coupl',
#       'tri',
#       'give',
#       'love',
#       'life',
#       'boost',
#       'take',
#       'impromptu',
#       'weekend',
#       'trip',
#       'onli',
#       'find',
#       'relationship',
#       'test',
#       'unexpect',
#       'way',
#       '.'],
#      'Tags': ['african',
#       'movi',
#       'psycholog',
#       'thriller',
#       'thriller',
#       'movi',
#       'mysteri',
#       'intern',
#       'thriller',
#       'steami',
#       'thriller',
#       'steami',
#       'thriller'],
#      'Title': 'Sin City',
#      'Writer': ['Robert Rodriguez', ' Frank Miller']},
#     '_type': '_doc'}],
#   'max_score': 9.963967,
#   'total': {'relation': 'eq', 'value': 6}},
#  'timed_out': False,
#  'took': 7}
